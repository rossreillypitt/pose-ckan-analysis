# %%
import csv
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from datetime import datetime, date
from dateutil import parser
import urllib3
import statistics
import warnings
import matplotlib.pyplot as plt
import seaborn
import numpy as np
from collections import Counter

# %%
datashades_raw_list = "shades.csv"

outside_list = ['http://data.ctdata.org/',
                'https://data.ci.newark.nj.us/',
                'https://open.jacksonms.gov/',
                'https://data.ca.gov/',
                'https://datagate.snap4city.org/'
                ]

def write_output_file(all_urls_final, filename):
    fieldnames = []
    for item in all_urls_final:
        if len(item.keys()) > len(fieldnames):
            fieldnames = item.keys()

    with open(filename, "w", encoding='utf-8', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)

        writer.writeheader()
        for item in all_urls_final:
            writer.writerow(item)

# %%
def datashades_clean_up(datashades_list):
    urls = []
    with open(datashades_list, newline="", encoding="utf-8") as f:
        reader = csv.reader(f)
        for row in reader:
            row_strip = row[0].strip()
            if row_strip[:5] == "href=":
                to_add = row_strip[37:-19]
                urls.append(to_add.split('%2F">')[0])
            else:
                pass

    clean_urls = []
    for item in urls:
        item = re.sub("%3A", ":", item)
        item = re.sub("%2F", "/", item)
        item = re.sub("%26", "%", item)
        item = re.sub("%3D", "=", item)
        item = re.sub("%3F", "?", item)
        item = re.sub("%23", "#", item)
        clean_urls.append(item)

    return clean_urls

def dataportals_clean_up():
    portals_df = pd.read_csv("https://raw.githubusercontent.com/okfn/dataportals.org/master/data/portals.csv")
    portals_list = list(portals_df.url)
    return portals_list

def url_setup(source, clean_urls):
    root_url_set = set()
    list_of_url_dicts_2 = []
    for item in clean_urls:
        root_url = item.split("/")[2]
        if root_url in root_url_set:
            pass
        else:
            root_url_set.add(root_url)
            url_dict = {}
            url_dict["source"] = source
            url_dict["source_url"] = item
            url_dict["root_url"] = root_url
            url_dict["base_url"] = item.split(root_url)[0]+root_url
            list_of_url_dicts_2.append(url_dict)
    return list_of_url_dicts_2

clean_shades_urls = datashades_clean_up(datashades_raw_list)
clean_portals_urls = dataportals_clean_up()
shades = url_setup("datashades.info", clean_shades_urls)
portals = url_setup("dataportals.org", clean_portals_urls)
wprdc = url_setup("WPRDC", outside_list)

# %%
def duplicate_removal_processing(list_of_lists_to_deduplicate):
    unique_urls = set()
    output_list = []
    for item in list_of_lists_to_deduplicate:
        for items in item:
            if items['root_url'] in unique_urls:
                pass
            else:
                output_list.append(items)
                unique_urls.add(items['root_url'])
    return output_list

list_of_lists = [shades, portals, wprdc]
combined_and_deduplicated = duplicate_removal_processing(list_of_lists)

# %%
len(combined_and_deduplicated)
# Out:
# 1031

# %%
def checking_for_response(passed_list):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
    full_error_list = []
    count = 0
    urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

    for item in passed_list:
        count+=1
        try:
            print(f'Now checking url #{count}: {item["source_url"]}')
            response = requests.get(item["source_url"], verify=False, headers=headers, timeout=120)
            status = response.status_code
            soup = BeautifulSoup(response.text, features="html.parser")
            name = str(soup.title.string)
            meta_tags = soup.find_all("meta")
            if len(meta_tags)>0:
                for element in meta_tags:
                    if element.get("name") == "generator":
                        generator = element.get("content")
                    else:
                        generator = ""
            else:
                generator = ""
        except AttributeError:
            name = "AttributeError"
        except requests.exceptions.SSLError as ssl_error:
            name = "SSL Error"
            generator = ""
        except requests.exceptions.ConnectionError as connect_error:
            name = "Connection Error"
            generator = ""
        except requests.exceptions.TooManyRedirects:
            name = "Too Many Redirects Error"
            generator = ""
        except requests.exceptions.Timeout:
            name = "Timeout"
            generator = ""
        except Exception as e:
                try:
                    name = e.response.text
                except:
                    name = "Error"
        item["name"] = name
        item["generator"] = generator
        item["status_code"] = status
    return passed_list

status_response = checking_for_response(combined_and_deduplicated)
# Out:
# Now checking url #1: https://data.cambridgeshireinsight.org.uk/search/field_topics/type/dataset?sort_by=changed
# Now checking url #2: https://africaopendata.org
# Now checking url #3: https://govtech.in.th
# Now checking url #4: https://opingogn.is
# Now checking url #5: http://data.openpolice.ru
# Now checking url #6: https://datos.agroindustria.gob.ar
# Now checking url #7: http://dados.ufrn.br
# Now checking url #8: http://data.odw.tw
# Now checking url #9: https://data.gov.ie
# Now checking url #10: https://geocatalogus.nl
# Now checking url #11: http://dados.mda.gov.br
# Now checking url #12: http://data.mariupolrada.gov.ua
# Now checking url #13: http://dados.ufop.br
# Now checking url #14: https://data.barrowbc.gov.uk
# Now checking url #15: https://opendata.ugr.es
# Now checking url #16: https://dados.uffs.edu.br
# Now checking url #17: http://portal.igg.ac.mn
# Now checking url #18: https://data.ed.gov
# Now checking url #19: http://opendata.gov.mn
# Now checking url #20: https://daten.rlp.de
# Now checking url #21: https://data.gov.il
# Now checking url #22: https://www.opengov-muenchen.de
# Now checking url #23: http://dados.df.gov.br
# Now checking url #24: https://ckan.jbrj.gov.br
# Now checking url #25: https://data.bart.gov
# Now checking url #26: https://opendata.plzen.eu
# Now checking url #27: http://ckan.gsi.go.jp
# Now checking url #28: https://data.nbco.gov.ie
# Now checking url #29: https://data.gov.mk
# Now checking url #30: https://data.imr.gov.ua
# Now checking url #31: http://dados.cvm.gov.br
# Now checking url #32: http://data.techno-science.ca
# Now checking url #33: http://data.ok.gov
# Now checking url #34: http://datos.santander.es
# Now checking url #35: http://geodm.gr
# Now checking url #36: https://gifu-opendata.pref.gifu.lg.jp
# Now checking url #37: https://gisdata.mn.gov
# Now checking url #38: http://opendata-ajuntament.barcelona.cat/data
# Now checking url #39: https://dati.trentino.it
# Now checking url #40: https://catalogue.data.wa.gov.au
# Now checking url #41: https://flooddata.ses.nsw.gov.au
# Now checking url #42: http://datos.jus.gob.ar
# Now checking url #43: https://www.data.go.jp/data
# Now checking url #44: https://dados.ons.org.br
# Now checking url #45: https://datos.alcobendas.org
# Now checking url #46: http://data.wonogirikab.go.id
# Now checking url #47: https://data.pompanobeachfl.gov
# Now checking url #48: http://130.179.67.140
# Now checking url #49: http://dados.cultura.gov.br
# Now checking url #50: http://opendata.manresa.cat
# Now checking url #51: http://www.fnde.gov.br/dadosabertos
# Now checking url #52: https://data.milwaukee.gov
# Now checking url #53: https://www.data.qld.gov.au
# Now checking url #54: https://unaids.fjelltopp.org
# Now checking url #55: https://data.england.nhs.uk
# Now checking url #56: https://data.nhm.ac.uk
# Now checking url #57: https://data.cbwaterhub.ca
# Now checking url #58: http://data.montreal.ca
# Now checking url #59: https://www.civicdata.io
# Now checking url #60: https://data.stadt-zuerich.ch
# Now checking url #61: https://datos.transporte.gob.ar
# Now checking url #62: https://datos.cultura.gob.ar
# Now checking url #63: http://proyectoarde.org/data
# Now checking url #64: https://www.data.brisbane.qld.gov.au/data
# Now checking url #65: https://data.bris.ac.uk/data
# Now checking url #66: http://catalog.industrie.gov.tn
# Now checking url #67: https://hubofdata.ru
# Now checking url #68: http://opendata.picturae.com
# Now checking url #69: https://data.datahub.freightaustralia.gov.au
# Now checking url #70: https://opendata.aragon.es/data/data
# Now checking url #71: http://opendata.awt.be
# Now checking url #72: https://opendata.bayern.de/data
# Now checking url #73: https://opendata.leipzig.de
# Now checking url #74: https://demo.ckan.org
# Now checking url #75: http://datos.qroo.gob.mx
# Now checking url #76: https://www.opendata.nhs.scot
# Now checking url #77: http://datos.gob.cl
# Now checking url #78: https://data.gov.au/data
# Now checking url #79: https://data.gov.hr
# Now checking url #80: http://agridata.tn
# Now checking url #81: https://data.stat.pref.miyazaki.lg.jp
# Now checking url #82: https://opendata.eol.org
# Now checking url #83: http://dadosabertos.iftm.edu.br
# Now checking url #84: http://opendata.hu
# Now checking url #85: http://opendatabc.ca
# Now checking url #86: http://liityntakatalogi.suomi.fi
# Now checking url #87: https://opendata.adico.fr
# Now checking url #88: http://data.waterpathogens.org
# Now checking url #89: https://ckan.earlham.ac.uk
# Now checking url #90: https://trouver.datasud.fr
# Now checking url #91: https://data.vic.gov.au/data
# Now checking url #92: http://linkeddatacatalog.dws.informatik.uni-mannheim.de
# Now checking url #93: http://opendata.slavrada.gov.ua
# Now checking url #94: https://data.yorkopendata.org
# Now checking url #95: https://datasets.datos.mincyt.gob.ar
# Now checking url #96: https://datacatalogue.gov.ie
# Now checking url #97: http://opendata.br7.org.il
# Now checking url #98: https://data.ontario.ca
# Now checking url #99: https://open.stavanger.kommune.no
# Now checking url #100: https://data.missouriepscor.org
# Now checking url #101: https://www.pigma.org/ckan
# Now checking url #102: https://datosabiertos.ayto-arganda.es
# Now checking url #103: https://catalog-intaros.nersc.no
# Now checking url #104: https://dados.antt.gov.br
# Now checking url #105: https://opendata.camden.gov.uk/browse?tags=planning%utf8=T%sortBy=relevance/data
# Now checking url #106: http://bermuda.io
# Now checking url #107: https://arcticatlas.geobotany.org/catalog
# Now checking url #108: https://datos.caf.com
# Now checking url #109: https://datasets.fieldsofview.in
# Now checking url #110: https://datos.gob.ar
# Now checking url #111: https://ckan.dev.pdnd.italia.it
# Now checking url #112: https://opendata.meerbusch.de
# Now checking url #113: http://dados.ufpi.br
# Now checking url #114: https://sprogteknologi.dk
# Now checking url #115: http://catalogue.simocean.pt
# Now checking url #116: http://datos.minfin.gob.gt
# Now checking url #117: https://ckan.grassroots.tools
# Now checking url #118: https://dadosabertos.bndes.gov.br
# Now checking url #119: https://pacificdata.org/data
# Now checking url #120: http://drdsi.jrc.ec.europa.eu
# Now checking url #121: http://data.surrey.ca
# Now checking url #122: http://dados.agricultura.gov.br
# Now checking url #123: https://scoda.co.za
# Now checking url #124: https://www.data.gov.my/data
# Now checking url #125: https://data.ehealthireland.ie
# Now checking url #126: https://ckan.fiware-testbed.jp
# Now checking url #127: https://opendata.ozwillo.com/fr
# Now checking url #128: http://datenregister.berlin.de
# Now checking url #129: https://staging.justicehub.in
# Now checking url #130: https://donneesquebec.ca/recherche/fr
# Now checking url #131: http://opendata.comune.bari.it
# Now checking url #132: http://dati.toscana.it
# Now checking url #133: https://www.data.gv.at/katalog
# Now checking url #134: http://opendata.imet.gr
# Now checking url #135: https://catalog.data.gov
# Now checking url #136: http://dados.recife.pe.gov.br
# Now checking url #137: https://ckancc.g-location-server.site
# Now checking url #138: https://data.gov.bf
# Now checking url #139: https://data.msmt.cz
# Now checking url #140: http://data.kk.dk
# Now checking url #141: http://dadosabertos.antaq.gov.br
# Now checking url #142: https://ckan.test-app.vwtelecom.com
# Now checking url #143: https://ckanmtp.ymparisto.fi
# Now checking url #144: https://apgc.awi.de
# Now checking url #145: https://dados.contraosagrotoxicos.org
# Now checking url #146: https://data.maintenance.org.au
# Now checking url #147: https://ckan-d4s.d4science.org
# Now checking url #148: http://dati.ustat.miur.it
# Now checking url #149: https://demo.datashades.com
# Now checking url #150: http://dati.comune.matera.it
# Now checking url #151: http://dato.chequeado.com
# Now checking url #152: http://knowledge.omaha.org.cn
# Now checking url #153: http://data.open.guelph.ca
# Now checking url #154: http://data.tegalkab.go.id
# Now checking url #155: http://opendatastore.brussels
# Now checking url #156: https://edx.netl.doe.gov
# Now checking url #157: https://govdata.de/ckan
# Now checking url #158: https://dataportal.geofyn.dk
# Now checking url #159: https://canwin-datahub.ad.umanitoba.ca/data
# Now checking url #160: https://data.vulekamali.gov.za
# Now checking url #161: https://www.geo2france.fr/ckan
# Now checking url #162: http://opendata.semarangkota.go.id
# Now checking url #163: https://data.sba.gov
# Now checking url #164: http://dados.ufes.br
# Now checking url #165: https://data-test.toll.no
# Now checking url #166: https://ckanviz.swige.unhcr.org
# Now checking url #167: https://datos.gob.sv
# Now checking url #168: http://dados.gov.br
# Now checking url #169: https://dadosabertos.prefeitura.poa.br
# Now checking url #170: https://opendata.mzcr.cz
# Now checking url #171: http://b2find.eudat.eu
# Now checking url #172: https://opendata.portdebarcelona.cat
# Now checking url #173: http://dados.mg.gov.br
# Now checking url #174: http://datos.techo.org
# Now checking url #175: https://data.cityofboston.gov
# Now checking url #176: http://opendata.ayto-caceres.es
# Now checking url #177: http://datos.misiones.gov.ar
# Now checking url #178: https://dados.ifsp.edu.br
# Now checking url #179: https://www.eia.gov/environment/data.php/data
# Now checking url #180: https://dadosabertos.senado.gov.br/data
# Now checking url #181: http://data.opendataportal.at
# Now checking url #182: https://data.cityofdenton.com
# Now checking url #183: http://data.zagreb.hr
# Now checking url #184: https://ckan.project-hobbit.eu
# Now checking url #185: http://ecaidata.org
# Now checking url #186: http://geodata.gov.gr
# Now checking url #187: https://avindata.ca
# Now checking url #188: http://dados.ibict.br
# Now checking url #189: https://data.aurin.org.au
# Now checking url #190: https://beta.ukdataservice.ac.uk/datacatalogue/studies/#!?Search=%Page=1%Rows=10%Sort=0%DateFrom=440%DateTo=2020/ckan
# Now checking url #191: http://dadosabertos.dataprev.gov.br
# Now checking url #192: https://opendata.euroinfosicilia.it
# Now checking url #193: https://datasets.catalogue.data.gov.dk
# Now checking url #194: https://katalog.data.go.id
# Now checking url #195: http://datapoa.com.br
# Now checking url #196: https://poc-api.excise.go.th
# Now checking url #197: https://usmart.io/#/org/angus/discovery?limit=20%offset=0%order=statistic.viewCount
# Now checking url #198: https://hub.satudata.bappenas.go.id
# Now checking url #199: https://ckan.pearlpv-cost.eu
# Now checking url #200: https://ckan.africadatahub.org
# Now checking url #201: https://oasishub.co
# Now checking url #202: https://dados.ufpr.br
# Now checking url #203: https://leedsdatamill.org
# Now checking url #204: http://annuario.comune.fi.it/ckan
# Now checking url #205: https://data.gov.md/ckan
# Now checking url #206: https://opendata.penghu.gov.tw
# Now checking url #207: https://datos.magyp.gob.ar
# Now checking url #208: http://edu.mrpam.gov.mn
# Now checking url #209: https://data.agglo-royan.fr
# Now checking url #210: http://dadosabertos.unilab.edu.br
# Now checking url #211: https://datos.do.magnet.cl
# Now checking url #212: https://opendata.oorlogsbronnen.nl
# Now checking url #213: https://dataplatformfiets.be
# Now checking url #214: https://data.sa.gov.au/data
# Now checking url #215: https://data.boston.gov
# Now checking url #216: https://data.city.osaka.lg.jp/data
# Now checking url #217: https://www.opendataphilly.org
# Now checking url #218: http://coat.nina.no/ckan
# Now checking url #219: http://data.houstontx.gov
# Now checking url #220: http://data.glasgow.gov.uk
# Now checking url #221: http://www.data.gov.ma/data
# Now checking url #222: http://data.birminghamal.gov
# Now checking url #223: http://dev.opencity.in
# Now checking url #224: https://opendata.alcoi.org/data
# Now checking url #225: http://openbaladiati.tn
# Now checking url #226: https://data.illinois.gov
# Now checking url #227: https://data.pkc.gov.uk
# Now checking url #228: http://mggl-ckan-web.asifarm.it
# Now checking url #229: http://www.ecaidata.org
# Now checking url #230: https://data.qld.gov.au
# Now checking url #231: https://dados.ufcspa.edu.br
# Now checking url #232: http://nosdonnees.fr
# Now checking url #233: https://transparencia.enargas.gov.ar
# Now checking url #234: https://api.foodsecurityportal.org
# Now checking url #235: https://ckan.pref.shizuoka.jp
# Now checking url #236: https://radius.amplusdata.io
# Now checking url #237: http://datosretc.mma.gob.cl
# Now checking url #238: https://tpbs.igenco.co.th
# Now checking url #239: https://data.gov.ua
# Now checking url #240: https://data.vbgov.com
# Now checking url #241: http://dati.mit.gov.it/catalog
# Now checking url #242: https://ckan.cabi.org/data
# Now checking url #243: https://www.donneesquebec.ca
# Now checking url #244: http://opendatalecce.apposta.biz
# Now checking url #245: https://podatki.gov.si
# Now checking url #246: http://data.gov.sk
# Now checking url #247: https://opendata.slavuta-mvk.gov.ua
# Now checking url #248: https://data.depositar.io
# Now checking url #249: http://data.pref.kyoto.lg.jp
# Now checking url #250: https://ckan.seki.jx.org
# Now checking url #251: http://data.pemalangkab.go.id
# Now checking url #252: https://offenedaten.de
# Now checking url #253: https://kod.brno.cz
# Now checking url #254: https://opendata.caceres.es
# Now checking url #255: https://datahub.io
# Now checking url #256: http://bmckan.cpami.gov.tw
# Now checking url #257: https://opendata.dev-vlaanderen.be
# Now checking url #258: http://dartportal.leeds.ac.uk
# Now checking url #259: https://data.nsw.gov.au/data
# Now checking url #260: https://opendata.gov.je
# Now checking url #261: https://dataportal.gov.tc
# Now checking url #262: https://dados.ifrn.edu.br
# Now checking url #263: http://data.open.guelph.ca.
# Now checking url #264: http://www.tesourotransparente.gov.br/ckan
# Now checking url #265: http://data.kalamazoocity.org
# Now checking url #266: https://gis-hub.ca
# Now checking url #267: https://datos.pami.org.ar
# Now checking url #268: https://data.lexingtonky.gov
# Now checking url #269: https://opendata.gov.cz/ckan
# Now checking url #270: https://ballaratopendata.org.au
# Now checking url #271: https://mobidata-bw.de
# Now checking url #272: http://data.transport.tn
# Now checking url #273: https://opendata.vlaanderen.be
# Now checking url #274: https://datos.aytolalaguna.es
# Now checking url #275: http://data.num.edu.mn
# Now checking url #276: https://opendata.com.pk
# Now checking url #277: http://data.gov.gr
# Now checking url #278: http://opendata.wigan.gov.uk/ckan
# Now checking url #279: https://danepubliczne.gov.pl/ckan
# Now checking url #280: https://portal.ai-global.org
# Now checking url #281: http://www.openculture.gov.tn
# Now checking url #282: http://datos.yvera.gob.ar
# Now checking url #283: http://dados.ifms.edu.br
# Now checking url #284: https://datosabiertos.bogota.gov.co
# Now checking url #285: https://data.gov.uk
# Now checking url #286: https://data.uni-hannover.de
# Now checking url #287: http://dadosjuventude.ibict.br
# Now checking url #288: https://datosabiertos.rivasciudad.es
# Now checking url #289: http://data.pekalongankota.go.id
# Now checking url #290: http://opendata.city.moka.lg.jp
# Now checking url #291: https://ckan.govdata.de
# Now checking url #292: http://opendata.worcesterma.gov
# Now checking url #293: https://data.hub.zamg.ac.at
# Now checking url #294: https://taijiang.tw
# Now checking url #295: https://data.purbalinggakab.go.id
# Now checking url #296: https://data.birmingham.gov.uk
# Now checking url #297: http://opendata.abbeville.fr
# Now checking url #298: http://dados.fortaleza.ce.gov.br
# Now checking url #299: http://opendatanepal.com
# Now checking url #300: http://data.agriculturelittorale.fr
# Now checking url #301: https://adr.unaids.org
# Now checking url #302: http://data.biodiversity.be
# Now checking url #303: http://dadosabertos.ifal.edu.br
# Now checking url #304: https://catalogue.nextgeoss.eu
# Now checking url #305: https://dataportal.eu-interact.org
# Now checking url #306: http://www.datapoa.com.br
# Now checking url #307: https://data.stirling.gov.uk
# Now checking url #308: http://dados.natal.br
# Now checking url #309: http://data-gov-ua.org
# Now checking url #310: http://ckan.geonet-mrn.de
# Now checking url #311: https://geoscience.data.qld.gov.au
# Now checking url #312: http://openkg.cn
# Now checking url #313: http://opendata.praha.eu
# Now checking url #314: https://opendata.med.kg
# Now checking url #315: https://opendata.mzp.cz
# Now checking url #316: http://datos.cali.gov.co
# Now checking url #317: https://data.gov.sg
# Now checking url #318: https://data.smartdublin.ie
# Now checking url #319: https://data.skeenasalmon.info
# Now checking url #320: https://data.opendevelopmentmekong.net
# Now checking url #321: https://ouvert.canada.ca/ckan
# Now checking url #322: https://ckan.otevrenamesta.cz
# Now checking url #323: https://data.overheid.nl/data
# Now checking url #324: https://catalogue.cioos.ca
# Now checking url #325: https://catalogue.ogsl.ca
# Now checking url #326: http://rotterdamopendata.nl
# Now checking url #327: http://dataportal.saeri.org//
# Now checking url #328: https://data.london.gov.uk/dataset
# Now checking url #329: https://openbudgetsindia.org
# Now checking url #330: http://publications.aberdeenshire.gov.uk
# Now checking url #331: http://dados.ufsm.br
# Now checking url #332: https://dados.ufrgs.br
# Now checking url #333: http://dados.al.gov.br
# Now checking url #334: https://datastore.landcareresearch.co.nz
# Now checking url #335: https://dados.ufca.edu.br
# Now checking url #336: https://dados.ifro.edu.br
# Now checking url #337: http://data.bayanat.ae
# Now checking url #338: https://library.atticawetlands.eu
# Now checking url #339: https://data.city.yokohama.lg.jp
# Now checking url #340: http://portal.opendata.dk
# Now checking url #341: https://hidalgo1.man.poznan.pl
# Now checking url #342: https://datos.mininterior.gob.ar
# Now checking url #343: https://ckan.sansa.saeoss.org
# Now checking url #344: https://datosabiertos.malaga.eu
# Now checking url #345: https://healthquery.sh.cn
# Now checking url #346: https://rdm.inesctec.pt
# Now checking url #347: http://portal.merit.mn
# Now checking url #348: http://portal.openbelgium.be
# Now checking url #349: http://datos.salud.gob.ar
# Now checking url #350: https://data.wprdc.org
# Now checking url #351: https://data.whiterockcity.ca/data
# Now checking url #352: https://data.tainan.gov.tw
# Now checking url #353: https://hri.fi/data
# Now checking url #354: http://opendata.aachen.de
# Now checking url #355: https://scidm.nchc.org.tw
# Now checking url #356: http://opendata.materaevents.it
# Now checking url #357: http://data.salzburgerland.com
# Now checking url #358: https://ckan.ev.openindustry.in
# Now checking url #359: http://www.transparencia.mg.gov.br/dados-abertos/ckan
# Now checking url #360: https://data.opendata.durban
# Now checking url #361: http://datango.infoculture.ru
# Now checking url #362: https://data.brisbane.qld.gov.au/data
# Now checking url #363: https://data.fingrid.fi
# Now checking url #364: http://datosabiertos.mendoza.gov.ar
# Now checking url #365: http://data.cilacapkab.go.id
# Now checking url #366: https://data.gov.cz
# Now checking url #367: http://datos.veracruzmunicipio.gob.mx
# Now checking url #368: http://dados.prefeitura.sp.gov.br
# Now checking url #369: http://data2.cerdi.edu.au
# Now checking url #370: http://opendata.fortsmithar.gov
# Now checking url #371: https://www.opendatani.gov.uk
# Now checking url #372: https://data.ioos.us
# Now checking url #373: https://opendata.e-land.gov.tw
# Now checking url #374: http://playdrive-lb-4.ezylink.co
# Now checking url #375: https://data.coat.no
# Now checking url #376: https://dataplatform.knmi.nl
# Now checking url #377: http://dadosabertos.ufersa.edu.br
# Now checking url #378: http://ngodata.ru
# Now checking url #379: https://opendata.sjgov.org
# Now checking url #380: https://dados.ifrs.edu.br
# Now checking url #381: https://transparencia.enargas.gob.ar
# Now checking url #382: https://gardentasuna.errenteria.eus/datuirekiak
# Now checking url #383: https://data.acehselatankab.go.id
# Now checking url #384: https://data.ecosis.org
# Now checking url #385: http://www.nosdonnees.fr
# Now checking url #386: https://www.opendata-hro.de
# Now checking url #387: http://opendata.mmdecin.cz
# Now checking url #388: https://data.buenosaires.gob.ar
# Now checking url #389: http://data.opencolorado.org
# Now checking url #390: http://iatiregistry.org
# Now checking url #391: https://maps.mapaction.org
# Now checking url #392: https://datasets.wri.org
# Now checking url #393: https://test.data.ontario.ca
# Now checking url #394: https://www.odata.org.il
# Now checking url #395: https://resiliencedata.nfwf.org
# Now checking url #396: https://data.balikpapan.go.id
# Now checking url #397: https://opendata.muenchen.de
# Now checking url #398: http://buildingamerica.openei.org
# Now checking url #399: https://dados.rs.gov.br
# Now checking url #400: http://pe.181.209.63.227.nip.io
# Now checking url #401: https://www.data.vic.gov.au/data
# Now checking url #402: http://data.mmr.cz
# Now checking url #403: https://data.kcg.gov.tw
# Now checking url #404: https://data.humdata.org
# Now checking url #405: https://opendata.cabq.gov
# Now checking url #406: http://ckan.opendatamalta.com
# Now checking url #407: http://dados.ifsertao-pe.edu.br
# Now checking url #408: http://dadosabertos.ifc.edu.br
# Now checking url #409: http://web.transparencia.pe.gov.br/ckan
# Now checking url #410: https://offenedaten.aachen.de
# Now checking url #411: http://dados.ifmt.edu.br
# Now checking url #412: https://data-portal.hpc.swin.edu.au
# Now checking url #413: https://dataurbe.appcivico.com
# Now checking url #414: http://data.sgm.ru
# Now checking url #415: https://data.review.fao.org/ckan
# Now checking url #416: http://datos.ambiente.gob.ar
# Now checking url #417: https://www.wvcheckbook.gov
# Now checking url #418: http://dados.ifsuldeminas.edu.br
# Now checking url #419: https://opendata.hautsdefrance.fr
# Now checking url #420: https://datasets.seed.nsw.gov.au
# Now checking url #421: https://data.tn.gov
# Now checking url #422: http://dados.tce.rs.gov.br
# Now checking url #423: https://opendata.city-adm.lviv.ua
# Now checking url #424: http://datar.noip.me
# Now checking url #425: http://opendata.go.tz
# Now checking url #426: http://digitalthailand.gistda.or.th
# Now checking url #427: https://data.tampere.fi/data
# Now checking url #428: http://catalogo.datosabiertos.gob.ec
# Now checking url #429: http://dados.ana.gov.br
# Now checking url #430: http://datosabiertos.fuengirola.es
# Now checking url #431: https://opendata.swiss
# Now checking url #432: https://ckan.pf-sapporo.jp
# Now checking url #433: http://dadosabertos.bcb.gov.br
# Now checking url #434: https://opendata.comune.re.it
# Now checking url #435: http://datosabiertos.mercedes.gob.ar
# Now checking url #436: https://dataut.vegvesen.no
# Now checking url #437: http://dataportal.smartcityinnovation.eu
# Now checking url #438: https://dadesobertes.salou.cat
# Now checking url #439: https://bigdata-metadados.icict.fiocruz.br
# Now checking url #440: https://dataworks.calderdale.gov.uk
# Now checking url #441: https://data.gov.lv
# Now checking url #442: http://datosestadistica.cba.gov.ar
# Now checking url #443: https://datos.congresogto.gob.mx
# Now checking url #444: https://opendatadafni.getmap.gr
# Now checking url #445: https://docs.entsoe.eu
# Now checking url #446: https://dati.arpae.it
# Now checking url #447: http://dados.unifesspa.edu.br
# Now checking url #448: https://dados.pbh.gov.br
# Now checking url #449: https://odata.org.il
# Now checking url #450: https://catalogue.data.gov.bc.ca
# Now checking url #451: https://ck.govdata.gov.br
# Now checking url #452: https://sprogressource.digst.govcloud.dk
# Now checking url #453: http://datos.minem.gob.ar
# Now checking url #454: https://claircitydata.cbs.nl
# Now checking url #455: https://repository.participatorylab.org
# Now checking url #456: https://dados.justica.gov.pt
# Now checking url #457: https://data.gov.hk/en-datasets/data
# Now checking url #458: https://data.amsterdam.nl/data
# Now checking url #459: https://data.cdc.gov.tw
# Now checking url #460: https://data.corkcity.ie
# Now checking url #461: http://dadosabertos.ufma.br
# Now checking url #462: https://datos.arsat.com.ar
# Now checking url #463: https://data.mempawahkab.go.id
# Now checking url #464: https://data.edincubator.eu
# Now checking url #465: http://data.sanjoseca.gov
# Now checking url #466: https://data.staging.sba.gov
# Now checking url #467: http://data.investigatemidwest.org
# Now checking url #468: http://datosabiertos.mineduc.gob.gt
# Now checking url #469: https://data.gov.sa/Data
# Now checking url #470: http://daten.buergernetz.bz.it
# Now checking url #471: https://data.env.go.jp
# Now checking url #472: https://data.nrri.umn.edu/data
# Now checking url #473: https://data.europa.eu/euodp/en/data
# Now checking url #474: http://dadosabertos.ibama.gov.br
# Now checking url #475: http://www.dados.univasf.edu.br
# Now checking url #476: http://transparencia.alhaurindelatorre.es
# Now checking url #477: https://dados.ufrr.br
# Now checking url #478: https://data.openstate.eu
# Now checking url #479: https://phoenixopendata.com
# Now checking url #480: http://opendata.lisra.jp
# Now checking url #481: https://bernco.civicdashboards.com
# Now checking url #482: http://datamx.io
# Now checking url #483: https://transparenz.karlsruhe.de
# Now checking url #484: http://data.gov.ro
# Now checking url #485: https://transportdata.be
# Now checking url #486: https://opendata.meteo.tn
# Now checking url #487: https://dataportal.smartme.io
# Now checking url #488: https://data.aberdeencity.gov.uk
# Now checking url #489: http://catalogo.governoaberto.sp.gov.br
# Now checking url #490: https://dataportal.cps.chula.ac.th
# Now checking url #491: https://www.odaa.dk/ckan
# Now checking url #492: http://data.ottawa.ca
# Now checking url #493: https://data.pontianakkota.go.id
# Now checking url #494: https://datenportal.pado-projekt.de
# Now checking url #495: https://www.donostia.eus/datosabiertos
# Now checking url #496: http://data.sanantonio.gov
# Now checking url #497: http://opendata.kp.gov.pk
# Now checking url #498: https://data.edinburghopendata.info
# Now checking url #499: https://salforddataquay.uk
# Now checking url #500: http://basedosdados.org
# Now checking url #501: https://opendata.nhsbsa.net
# Now checking url #502: https://dadosabertos.ufms.br
# Now checking url #503: http://dadosabertos.capes.gov.br
# Now checking url #504: http://opendata.angus.gov.uk
# Now checking url #505: https://open.canada.ca/data
# Now checking url #506: https://data.doi.gov
# Now checking url #507: https://offenedaten.frankfurt.de
# Now checking url #508: http://dados.ufpel.edu.br
# Now checking url #509: https://finrahoitus.fi/data
# Now checking url #510: http://www.basedosdados.org
# Now checking url #511: http://datospublicos.org/ckan
# Now checking url #512: https://avoindata.fi/data
# Now checking url #513: http://data.treasury.ri.gov
# Now checking url #514: http://dados.mma.gov.br
# Now checking url #515: http://donnees.ville.montreal.qc.ca
# Now checking url #516: http://www.transparencia.dadosabertos.mg.gov.br
# Now checking url #517: http://www.a2gov.org/services/data/Pages/default.aspx
# Now checking url #518: http://acikveri.sahinbey.bel.tr/dataset
# Now checking url #519: http://opendata.tarragona.cat/
# Now checking url #520: http://opendata.terrassa.cat/
# Now checking url #521: http://open.alabama.gov/
# Now checking url #522: http://open.data.al/
# Now checking url #523: https://open.alberta.ca
# Now checking url #524: http://algeria.opendataforafrica.org/
# Now checking url #525: http://www.alkmaar.nl/opendata
# Now checking url #526: http://www.allerdale.gov.uk/default.aspx?Page=2288
# Now checking url #527: http://www.gisdro.nl/open_geodata/
# Now checking url #528: http://www.amsterdamopendata.nl/home
# Now checking url #529: http://www.juntadeandalucia.es/datosabiertos/portal.html
# Now checking url #530: http://data.angers.fr/
# Now checking url #531: http://arvada.org/opendata
# Now checking url #532: http://risp.asturias.es
# Now checking url #533: http://data.vorarlberg.gv.at/
# Now checking url #534: https://www1.data.antarctica.gov.au
# Now checking url #535: http://ada.edu.au
# Now checking url #536: http://aihw.gov.au/data-by-subject/
# Now checking url #537: https://observa.gijon.es/
# Now checking url #538: http://datos.madrid.es/
# Now checking url #539: http://badalona.cat/portalWeb/badalona.portal?_nfpb=true&_pageLabel=opendata
# Now checking url #540: http://www.bahrain.bh/wps/portal/data/
# Now checking url #541: http://www.data.gov.bh/
# Now checking url #542: http://www.banffopendata.ca/
# Now checking url #543: https://data.bathhacked.org/
# Now checking url #544: http://www.bcn.cat/opendata/
# Now checking url #545: http://www.bjdata.gov.cn/
# Now checking url #546: http://daten.berlin.de/
# Now checking url #547: http://www.bilbao.net/opendata
# Now checking url #548: http://www.birmingham.gov.uk/open-data
# Now checking url #549: http://www.bizstats.co.uk/
# Now checking url #550: http://dati.comune.bologna.it/
# Now checking url #551: http://hubmaps1.cityofboston.gov/datahub/
# Now checking url #552: http://data.visitprovence.com/
# Now checking url #553: http://www.brampton.ca/EN/City-Hall/OpenGov/Pages/Welcome.aspx
# Now checking url #554: http://opengov.brandon.ca/open-government.aspx
# Now checking url #555: https://opendata.bristol.gov.uk/
# Now checking url #556: http://budget.gov.ru/
# Now checking url #557: http://cms.burlington.ca/Page7429.aspx
# Now checking url #558: http://opendata.busan.go.kr/
# Now checking url #559: http://www.data.ca.gov
# Now checking url #560: http://opendata.gov.nl.ca
# Now checking url #561: http://app.kitchener.ca/opendata/
# Now checking url #562: http://climate.calcommons.org/lists/datasets
# Now checking url #563: http://www.caib.es/caibdatafront/
# Now checking url #564: https://cityonline.calgary.ca/opendata
# Now checking url #565: http://chhs.data.ca.gov
# Now checking url #566: http://opendata.cambridgeshireinsight.org.uk/
# Now checking url #567: http://www.linkedopencamera.it/index.php/i-dati
# Now checking url #568: http://cameroon.opendataforafrica.org/
# Now checking url #569: http://caboverde.opendataforafrica.org/
# Now checking url #570: http://centraldedados.pt
# Now checking url #571: http://dati.camera.it/it/
# Now checking url #572: http://www.chatham-kent.ca/sp_training/OpenData/Pages/DataCatalogue.aspx
# Now checking url #573: https://data.chattlibrary.org/
# Now checking url #574: https://data.cityofchicago.org/
# Now checking url #575: http://datos.bcn.cl/
# Now checking url #576: http://www.consejotransparencia.cl/consejo/site/edic/base/port/pcatalogo.html
# Now checking url #577: http://www.chilliwack.com/main/page.cfm?id=2329
# Now checking url #578: http://govinfo.nlc.gov.cn/
# Now checking url #579: https://opendurham.nc.gov/
# Now checking url #580: https://data.honolulu.gov/
# Now checking url #581: https://data-avl.opendata.arcgis.com/
# Now checking url #582: https://data.austintexas.gov/
# Now checking url #583: https://data.brla.gov/
# Now checking url #584: https://bouldercolorado.gov/open-data/
# Now checking url #585: https://data.culvercity.org/
# Now checking url #586: https://data.detroitmi.gov/
# Now checking url #587: http://data.grcity.us/
# Now checking url #588: https://data.kcmo.org/
# Now checking url #589: https://opendata.lasvegasnevada.gov/
# Now checking url #590: https://data.lacity.org/
# Now checking url #591: https://data.cityofmadison.com/
# Now checking url #592: http://opendata.minneapolismn.gov/
# Now checking url #593: http://data.cityofpaloalto.org/
# Now checking url #594: http://data.cityofpasadena.net/
# Now checking url #595: https://data.providenceri.gov/
# Now checking url #596: https://data.richmondgov.com/
# Now checking url #597: http://data.cityofsacramento.org/
# Now checking url #598: http://data.santa-clarita.com/
# Now checking url #599: https://data.smgov.net/
# Now checking url #600: http://opendata.waterloo.ca/
# Now checking url #601: https://data.weho.org/
# Now checking url #602: http://www.cityscale.com.ua/
# Now checking url #603: http://www.citywindsor.ca/003713.asp
# Now checking url #604: http://www.civicapps.org/datasets
# Now checking url #605: http://ie.ckan.net/
# Now checking url #606: http://br.ckan.net/
# Now checking url #607: http://it.ckan.net/
# Now checking url #608: http://rs.ckan.net/
# Now checking url #609: http://datos.codeandomexico.org/
# Now checking url #610: http://www.colorado.gov/data/
# Now checking url #611: http://www.comune.palermo.it/opendata.php
# Now checking url #612: http://dati.comune.milano.it/
# Now checking url #613: http://dati.comune.roma.it/
# Now checking url #614: http://transparency.ct.gov/html/main.asp
# Now checking url #615: http://data.cookcountyil.gov/
# Now checking url #616: http://www.opendatacordoba.com
# Now checking url #617: http://www.criik.com/
# Now checking url #618: https://data.csiro.au/
# Now checking url #619: http://data.lacub.fr/
# Now checking url #620: http://cz.ckan.net/
# Now checking url #621: http://arenysdemunt.smartgovs.info/
# Now checking url #622: http://dados.novohamburgo.rs.gov.br
# Now checking url #623: http://data.daejeon.go.kr/
# Now checking url #624: http://zwgk.dl.gov.cn/
# Now checking url #625: https://www.dallasopendata.com/
# Now checking url #626: http://www.open.canada.ca/
# Now checking url #627: https://www.data.go.kr
# Now checking url #628: http://www.data.gov/catalog
# Now checking url #629: http://data.mos.ru
# Now checking url #630: http://www.gov.hk/en/theme/psi
# Now checking url #631: http://data.seattle.gov/
# Now checking url #632: http://www.datosabiertos.jcyl.es/
# Now checking url #633: http://data.gv.at/
# Now checking url #634: http://data.linz.gv.at/
# Now checking url #635: http://opendata.admin.ch/
# Now checking url #636: http://data.civicinfo.ca/
# Now checking url #637: https://data.colorado.gov/
# Now checking url #638: http://abertos.xunta.es/
# Now checking url #639: http://data.go.jp
# Now checking url #640: http://data.go.th/
# Now checking url #641: http://www.data.gouv.fr/
# Now checking url #642: http://data.gov.ph
# Now checking url #643: http://data.gov.tw/
# Now checking url #644: https://data.hartford.gov/
# Now checking url #645: http://data.lincoln.ac.uk/
# Now checking url #646: http://datameti.go.jp/
# Now checking url #647: http://data.norge.no/
# Now checking url #648: http://www.data-publica.com/
# Now checking url #649: http://data.ukmin.lt/
# Now checking url #650: http://data.ulm.de/
# Now checking url #651: https://data.act.gov.au/
# Now checking url #652: http://datacatalogs.org/
# Now checking url #653: http://www.data.ug
# Now checking url #654: http://www.datagm.org.uk
# Now checking url #655: http://datagov.ru/
# Now checking url #656: http://datakilder.no
# Now checking url #657: http://datalocale.fr
# Now checking url #658: http://datasf.org
# Now checking url #659: http://www.datashanghai.gov.cn
# Now checking url #660: http://opendata.service-bw.de/Seiten/default.aspx
# Now checking url #661: http://www.daten.bremen.de/
# Now checking url #662: http://dati.veneto.it/
# Now checking url #663: http://dati.emilia-romagna.it/
# Now checking url #664: http://dati.gov.it
# Now checking url #665: https://www.dati.lombardia.it/
# Now checking url #666: http://www.datiopen.it/
# Now checking url #667: http://www.datos.misiones.gov.ar/
# Now checking url #668: http://datosabiertos.munlima.gob.pe/
# Now checking url #669: https://catalogodatos.gub.uy/
# Now checking url #670: http://datos.org.py
# Now checking url #671: http://datos.transparencia.gob.gt/
# Now checking url #672: http://www.datosabiertos.df.gob.mx/
# Now checking url #673: http://www.datosperu.org/
# Now checking url #674: http://data.octo.dc.gov
# Now checking url #675: http://data.denvergov.org/
# Now checking url #676: http://data.digitaliser.dk
# Now checking url #677: http://opendata.dc.gov/
# Now checking url #678: http://geoweb.dnv.org/data/
# Now checking url #679: http://drcongo.opendataforafrica.org/
# Now checking url #680: http://www.dublinked.ie/datastore/index.php
# Now checking url #681: http://e-data.gov.ua/
# Now checking url #682: https://earthworks.stanford.edu
# Now checking url #683: https://data.edmonton.ca/
# Now checking url #684: http://www.eduinfo.co.uk/
# Now checking url #685: http://ckan.emap.fgv.br
# Now checking url #686: http://data.enel.com
# Now checking url #687: https://data.sa.edu.au/
# Now checking url #688: http://gptogc.esri.com/geoportal
# Now checking url #689: http://ethiopia.opendataforafrica.org/
# Now checking url #690: http://open-data.europa.eu/
# Now checking url #691: https://www.europeandataportal.eu/
# Now checking url #692: http://opendata.euskadi.net
# Now checking url #693: http://ckan.net/tag/read/eutransparency
# Now checking url #694: http://www.extremadurareutiliza.es/
# Now checking url #695: http://datanest.fair-play.sk/datasets
# Now checking url #696: http://data.fingal.ie/
# Now checking url #697: http://beta.avoindata.fi/
# Now checking url #698: http://www.fredericton.ca/en/citygovernment/DataMain.asp
# Now checking url #699: http://data.gwd.go.kr/
# Now checking url #700: http://www.gatineau.ca/donneesouvertes/
# Now checking url #701: http://dadesobertes.gencat.cat
# Now checking url #702: http://data.gent.be
# Now checking url #703: https://www.geo.be
# Now checking url #704: http://geocommons.com
# Now checking url #705: http://www.comune.vicenza.it/ente/settori/dipgenpers/sistinf/sit/daticartografici.php
# Now checking url #706: http://www.open.georgia.gov/
# Now checking url #707: http://www.opendata.ge
# Now checking url #708: http://www.geodata.gov
# Now checking url #709: http://ghana.opendataforafrica.org/
# Now checking url #710: http://ghdx.org
# Now checking url #711: http://datos.gijon.es
# Now checking url #712: http://www.gipuzkoairekia.eus
# Now checking url #713: http://www.datalocale.fr/
# Now checking url #714: http://www.gogeo.ac.uk
# Now checking url #715: http://gong.io/
# Now checking url #716: http://www.data.gov.bc.ca/
# Now checking url #717: http://www.governoaberto.sp.gov.br
# Now checking url #718: http://data.countygp.ab.ca/
# Now checking url #719: http://catalogue.data.grandlyon.com/
# Now checking url #720: http://data.graz.gv.at
# Now checking url #721: http://datagm.org.uk/
# Now checking url #722: http://data.groningen.nl
# Now checking url #723: http://www.guardian.co.uk/world-government-data
# Now checking url #724: http://openguelph.wpengine.com/open-data-guelph/
# Now checking url #725: http://open.gwangju.go.kr/
# Now checking url #726: http://data.gg.go.kr/
# Now checking url #727: https://www.halifaxopendata.ca/
# Now checking url #728: http://daten.hamburg.de/
# Now checking url #729: http://www.hamilton.ca/ProjectsInitiatives/OpenData/
# Now checking url #730: http://opendata.hauts-de-seine.net/
# Now checking url #731: http://www.healthdata.gov/
# Now checking url #732: http://www.hri.fi
# Now checking url #733: http://data.codeforhouston.com/
# Now checking url #734: https://gisdata-istc.opendata.arcgis.com/
# Now checking url #735: http://www.igeo.pt/
# Now checking url #736: http://open.incheon.go.kr/
# Now checking url #737: http://data.gov.in/
# Now checking url #738: http://data.go.id
# Now checking url #739: http://data.jakarta.go.id
# Now checking url #740: http://data.jeju.go.kr/
# Now checking url #741: http://data.jyvaskyla.fi
# Now checking url #742: http://www.kamloops.ca/downloads/maps/launch.htm
# Now checking url #743: http://data.kaohsiung.gov.tw/Opendata/
# Now checking url #744: http://data.klp.org.in/
# Now checking url #745: http://www.kelowna.ca/CM/Page3936.aspx
# Now checking url #746: http://www.datakc.org/
# Now checking url #747: http://www.cityofkingston.ca/explore/data-catalogue
# Now checking url #748: http://data.datahub.kr
# Now checking url #749: http://data.lanacion.com.ar/
# Now checking url #750: http://data.ktn.gv.at/
# Now checking url #751: http://www.lemans.fr/page.do?t=2&uuid=16CB26C7-550EA533-5AE8381B-D7A64AF8
# Now checking url #752: http://www.apileipzig.de/
# Now checking url #753: http://www2.lichfielddc.gov.uk/data/
# Now checking url #754: http://data.reegle.info/
# Now checking url #755: http://data.loire-atlantique.fr/
# Now checking url #756: http://localdata.net.au/
# Now checking url #757: http://www.london.ca/city-hall/open-data/Pages/Open-Data-Data-Catalogue.aspx
# Now checking url #758: http://portal.louisvilleky.gov/service/data
# Now checking url #759: http://www.maine.gov/cgi-bin/data/index.pl
# Now checking url #760: http://malawi.opendataforafrica.org/
# Now checking url #761: http://mapyourtaxes.mo.gov/MAP/Portal/Default.aspx
# Now checking url #762: https://wiki.state.ma.us/confluence/display/data/Open+Data+Initiative+Home
# Now checking url #763: http://www.medfloss.org
# Now checking url #764: http://data.medicinehat.ca/
# Now checking url #765: https://data.melbourne.vic.gov.au
# Now checking url #766: http://data.melbournewater.opendata.arcgis.com
# Now checking url #767: http://www.merton.gov.uk/council/dp-foi/opendata.htm
# Now checking url #768: http://www.metrobostondatacommon.org/
# Now checking url #769: https://data.nashville.gov/
# Now checking url #770: https://opendata.miamidade.gov/
# Now checking url #771: http://www.michigan.gov/som/0,1607,7-192-29938_54272---,00.html
# Now checking url #772: http://icreateopendata.public.esolutionsgroup.ca/
# Now checking url #773: http://www.mindbigdata.com/opendb
# Now checking url #774: http://www.state.mn.us/data/
# Now checking url #775: http://www.mississauga.ca/portal/residents/publicationsopendatacatalogue
# Now checking url #776: http://www.offenedaten.moers.de/
# Now checking url #777: http://datos.montevideo.gub.uy
# Now checking url #778: http://opendata.montpelliernumerique.fr
# Now checking url #779: http://data.gov.ma/
# Now checking url #780: http://morocco.opendataforafrica.org/
# Now checking url #781: http://data.mosman.nsw.gov.au/
# Now checking url #782: http://mozambique.opendataforafrica.org/
# Now checking url #783: http://www.mulhouse.fr/fr/les-donnees/
# Now checking url #784: http://datos.gob.mx/
# Now checking url #785: http://namibia.opendataforafrica.org/
# Now checking url #786: http://data.nanaimo.ca/
# Now checking url #787: http://data.nantes.fr
# Now checking url #788: http://dati.istat.it/
# Now checking url #789: http://www.avoindata.fi
# Now checking url #790: http://www.naturalearthdata.com/
# Now checking url #791: http://opendata.navarra.es
# Now checking url #792: http://www.ncopenbook.gov/NCOpenBook/
# Now checking url #793: http://opendatanederland.org
# Now checking url #794: http://www.neii.gov.au
# Now checking url #795: https://data-nevcounty.opendata.arcgis.com/
# Now checking url #796: http://data.nola.gov/
# Now checking url #797: http://www.niagararegion.ca/government/opendata/default.aspx
# Now checking url #798: http://www.niagarafalls.ca/services/open/data
# Now checking url #799: http://data.noe.gv.at/
# Now checking url #800: http://nigeria.opendataforafrica.org/
# Now checking url #801: https://www.northdevon.gov.uk/council/data-protection-and-freedom-of-information/publication-scheme/open-data/
# Now checking url #802: http://www.nd.gov/gis/
# Now checking url #803: http://data.gb.go.kr/
# Now checking url #804: http://opendata.go.kr/
# Now checking url #805: http://www.rdno.ca/index.php/maps/digital-data
# Now checking url #806: http://www.opendatanottingham.org.uk/
# Now checking url #807: https://www.nysenate.gov/open-data
# Now checking url #808: http://nycopendata.socrata.com/
# Now checking url #809: http://oakville.ca/data/
# Now checking url #810: http://opendata.odiqueensland.org.au/
# Now checking url #811: http://www.offenes-jena.de
# Now checking url #812: http://www.mo.gov/data/
# Now checking url #813: http://www.floridahasarighttoknow.com/
# Now checking url #814: http://www.rdos.bc.ca/departments/information-services/open-data-downloads/
# Now checking url #815: http://www.data.gov.om/
# Now checking url #816: https://www.ost.pt
# Now checking url #817: http://www.ontario.ca/government/open-data-ontario
# Now checking url #818: http://www.opendatahub.it/
# Now checking url #819: http://www.opendata.tw/
# Now checking url #820: http://www.comune.trento.it/comunicazione/trasparenza/open-data
# Now checking url #821: http://www.saudi.gov.sa/wps/portal/!ut/p/c5/04_SB8K8xLLM9MSSzPy8xBz9CP0os3iTMGenYE8TIwODUEsLA89QU69g11A_YwMTQ6B8JJK8u68jUD44OCQwMNDd0MDQnBLdRhTpDjYgRrcBDuBISHdwap5-OCi08Psen7wRAXmQD0DyeNzo55Gfm6pfkBsaGhpR4ZkZkK4IAOm0c0U!/dl3/d3/L0lHSkovd0RNQUprQUVnQSEhL1lCZncvYXI!/?
# Now checking url #822: http://data.wien.gv.at/
# Now checking url #823: http://www.tn.gov/opengov/
# Now checking url #824: https://data.ny.gov/
# Now checking url #825: http://cat.open.org.nz/category/dataset/
# Now checking url #826: http://data.openva.com/
# Now checking url #827: http://opendata.antwerpen.be/datasets
# Now checking url #828: http://www.datos.gov.co/
# Now checking url #829: http://dati.comune.firenze.it
# Now checking url #830: http://opendataforafrica.org/
# Now checking url #831: http://opendatakosovo.org/data/
# Now checking url #832: http://sierraleone.opendataforafrica.org/
# Now checking url #833: http://opendata.gov.sl/
# Now checking url #834: http://catalog.opendata.in.th/
# Now checking url #835: http://www.opendevelopmentcambodia.net/
# Now checking url #836: http://www.openkent.org.uk
# Now checking url #837: https://data.raleighnc.gov
# Now checking url #838: http://open.stockholm.se/
# Now checking url #839: http://www.openumea.se/
# Now checking url #840: http://openaid.se/
# Now checking url #841: http://data.baltimorecity.gov/
# Now checking url #842: http://opendata.enschede.nl
# Now checking url #843: http://www.opendata.go.ke
# Now checking url #844: http://opendata.bonn.de/
# Now checking url #845: http://opendata.brussel.be/
# Now checking url #846: http://www.opendata.hu
# Now checking url #847: http://opendata.lv/
# Now checking url #848: http://www.opendatabc.ca/?app=odcat2
# Now checking url #849: http://www.manchester.gov.uk/info/500215/open_data
# Now checking url #850: http://www.opendataterritorioenna.it
# Now checking url #851: http://opendoor.ky.gov/transparency/Pages/default.aspx
# Now checking url #852: http://en.openei.org/
# Now checking url #853: http://opengov.es
# Now checking url #854: http://www.opengov.se/data
# Now checking url #855: http://opengovdata.ru
# Now checking url #856: https://open.nrw
# Now checking url #857: http://www.openstreetmap.org
# Now checking url #858: http://oppnadata.se/
# Now checking url #859: http://www.orebro.se/psidata
# Now checking url #860: http://data.oregon.gov/
# Now checking url #861: http://www.os.amsterdam.nl/
# Now checking url #862: http://www.ouka.fi/oulu/oulu-tietoa/avoin-data
# Now checking url #863: http://cartolleida.paeria.es/lleidaoberta/inici.aspx
# Now checking url #864: http://pamplona.es/verPagina.asp?IdPag=1519&Idioma=1
# Now checking url #865: http://opendata.paris.fr/
# Now checking url #866: http://www.comune.pv.it/site/home/dai-settori-e-servizi/servizio-informatico-comunale/s.i.t.-sistema-informativo-territoriale/download-dati-geografici.html
# Now checking url #867: http://picandmix.org.uk/categories/
# Now checking url #868: http://www.dati.piemonte.it
# Now checking url #869: http://opendata.jccm.es/
# Now checking url #870: http://www.despesapublica.com/#sortorder=desc
# Now checking url #871: http://princegeorge.ca/cityservices/online/odc/Pages/Documents.aspx
# Now checking url #872: http://opendata.provincia.lucca.it/
# Now checking url #873: http://www.opendata.provincia.roma.it/
# Now checking url #874: http://www.dados.gov.pt/
# Now checking url #875: https://pub.uni-bielefeld.de/data
# Now checking url #876: https://www.infomex.org.mx/gobiernofederal/homeOpenData.action
# Now checking url #877: http://publicdata.belgium.be
# Now checking url #878: http://publicdata.eu/
# Now checking url #879: http://www.dati.puglia.it/
# Now checking url #880: http://data.gouv.qc.ca/
# Now checking url #881: http://qldspatial.information.qld.gov.au/
# Now checking url #882: http://donnees.ville.quebec.qc.ca/
# Now checking url #883: http://rcongo.opendataforafrica.org/
# Now checking url #884: http://www.recovery.gov/
# Now checking url #885: http://data.reddeer.ca/
# Now checking url #886: http://data.redbridge.gov.uk/
# Now checking url #887: http://www.regina.ca/residents/open-government/data/
# Now checking url #888: http://www.york.ca/opendata
# Now checking url #889: http://opendata.peelregion.ca/
# Now checking url #890: http://www.regionofwaterloo.ca/opendata
# Now checking url #891: http://www.data.rennes-metropole.fr
# Now checking url #892: http://researchdata.ands.org.au/
# Now checking url #893: http://www.ri.gov/data
# Now checking url #894: http://www.opendata.larochelle.fr/
# Now checking url #895: http://www.rotterdamopendata.nl/
# Now checking url #896: http://rwanda.opendataforafrica.org/
# Now checking url #897: http://www.saanich.ca/data/catalogue/index.php
# Now checking url #898: http://www.salford.gov.uk/opendata.htm
# Now checking url #899: http://sdappschallenge.com/details/data
# Now checking url #900: http://data.cityofsantacruz.com/
# Now checking url #901: http://www.opendata71.fr/
# Now checking url #902: http://www.sardegnageoportale.it/index.html
# Now checking url #903: http://opendata-saskatoon.cloudapp.net/
# Now checking url #904: http://data.sejong.go.kr/
# Now checking url #905: http://www.semic.eu/semic/view/snav/assetRepository.xhtml
# Now checking url #906: http://dati.senato.it/
# Now checking url #907: http://senegal.opendataforafrica.org/
# Now checking url #908: http://data.seoul.go.kr
# Now checking url #909: http://donnees.ville.sherbrooke.qc.ca/
# Now checking url #910: http://slip.landgate.wa.gov.au
# Now checking url #911: http://open.gsnd.net/
# Now checking url #912: http://data.jeonnam.go.kr/
# Now checking url #913: https://web1.capetown.gov.za/web1/opendataportal/Default
# Now checking url #914: https://municipalmoney.gov.za
# Now checking url #915: https://municipaldata.treasury.gov.za
# Now checking url #916: http://southafrica.opendataforafrica.org/
# Now checking url #917: https://vulekamali.gov.za/
# Now checking url #918: http://southsudan.opendataforafrica.org/
# Now checking url #919: http://datos.gob.es
# Now checking url #920: https://data.sunshinecoast.qld.gov.au/
# Now checking url #921: http://www.statcentral.ie/
# Now checking url #922: http://www.nebraska.gov/data/
# Now checking url #923: http://data.wa.gov/
# Now checking url #924: http://www.strathcona.ca/local-government/strathcona-county-elections/election-2013-open-data/
# Now checking url #925: http://data.suomi.fi
# Now checking url #926: http://www.surrey.ca/city-services/658.aspx
# Now checking url #927: http://www.sutton.gov.uk
# Now checking url #928: http://data.taichung.gov.tw/
# Now checking url #929: http://tampere.fi/avoindata
# Now checking url #930: http://tanzania.opendataforafrica.org/
# Now checking url #931: http://www.texas.gov/en/Connect/Pages/open-data.aspx
# Now checking url #932: http://www.texastransparency.org/opendata/index.php
# Now checking url #933: http://data.pm.go.th/
# Now checking url #934: http://www.thunderbay.ca/Living/Getting_Around/Thunder_Bay_Transit/Developers_-_Open_Data.htm
# Now checking url #935: http://data.tirol.gv.at
# Now checking url #936: http://www.tol.ca/ServicesContact/OpenData/OpenDataCatalogue.aspx
# Now checking url #937: http://www.comune.torino.it/aperto
# Now checking url #938: http://www.toronto.ca/open
# Now checking url #939: http://data.grandtoulouse.fr/
# Now checking url #940: http://www.trafford.gov.uk/opendata
# Now checking url #941: http://www.turkstat.gov.tr/Start.do;jsessionid=hzjxJZtK13J4NGP6PxvfdJGkFJMtZLSWdwpy29hy34Dc6pTk09B9!926848241
# Now checking url #942: http://tunisia.opendataforafrica.org/
# Now checking url #943: http://paikkatietokeskus.lounaispaikka.fi/fi/aineistot/
# Now checking url #944: http://www.government.ae/web/guest/uae-data
# Now checking url #945: http://data.ulsan.go.kr/
# Now checking url #946: http://open.unhabitat.org/
# Now checking url #947: http://www.undata-api.org/wiki/datasets
# Now checking url #948: https://servizi.comune.cesena.fc.it/opendata/
# Now checking url #949: http://data.ox.ac.uk/
# Now checking url #950: http://data.southampton.ac.uk/home.html
# Now checking url #951: http://enforcedata.dol.gov
# Now checking url #952: http://usaspending.gov/
# Now checking url #953: http://www.utah.gov/data/
# Now checking url #954: http://data.vancouver.ca/datacatalogue/index.htm
# Now checking url #955: http://dati.venezia.it/
# Now checking url #956: http://www.vernon.ca/map/
# Now checking url #957: http://vicroadsopendata.vicroadsmaps.opendata.arcgis.com/
# Now checking url #958: http://www.victoria.ca/EN/main/city/open-data-catalogue.html
# Now checking url #959: http://opendata.bordeaux.fr/
# Now checking url #960: http://datapoint.apa.virginia.gov/
# Now checking url #961: http://opendata.warwickshire.gov.uk/datasets/
# Now checking url #962: http://www.welland.ca/open/Opendata.asp
# Now checking url #963: http://data.wa.gov.au/
# Now checking url #964: http://data.whitehorse.ca/
# Now checking url #965: https://data.winnipeg.ca/
# Now checking url #966: http://winnipegelection.ca/open_data_2010
# Now checking url #967: http://developer.worldbank.org
# Now checking url #968: http://www.wyre.gov.uk/opendata
# Now checking url #969: http://zambia.opendataforafrica.org/
# Now checking url #970: http://datos.zaragoza.es
# Now checking url #971: http://zimbabwe.opendataforafrica.org/
# Now checking url #972: http://opendata.government.bg/
# Now checking url #973: https://data.hawaii.gov
# Now checking url #974: https://openaq.org
# Now checking url #975: http://geoinfo.msl.mt.gov/
# Now checking url #976: http://data-mtfwp.opendata.arcgis.com/
# Now checking url #977: https://github.com/openbounds
# Now checking url #978: https://www.dataplatform.nl/
# Now checking url #979: http://data.bandaacehkota.go.id/
# Now checking url #980: http://geo.gob.bo/
# Now checking url #981: http://data.telangana.gov.in/
# Now checking url #982: http://data.g0vhk.io
# Now checking url #983: http://www.geoguyane.fr/accueil/catalogue/
# Now checking url #984: http://www.otvorenipodatoci.gov.mk
# Now checking url #985: http://armstat.am/en/
# Now checking url #986: https://data.gov.rs
# Now checking url #987: https://data.linz.govt.nz
# Now checking url #988: https://www.lincolnshire.gov.uk/opendata
# Now checking url #989: https://opendata.tel-aviv.gov.il/#/
# Now checking url #990: http://data.culturecommunication.gouv.fr/
# Now checking url #991: https://nepalmap.org/
# Now checking url #992: https://dadosabertos.camara.leg.br/
# Now checking url #993: http://api.tcm.ce.gov.br/
# Now checking url #994: https://transparencia.es.gov.br/DadosAbertos/BaseDeDados#
# Now checking url #995: http://www.transparencia.go.gov.br/portaldatransparencia/institucional/dados-abertos
# Now checking url #996: http://dadosabertos.almg.gov.br/ws/ajuda/sobre
# Now checking url #997: http://portal.tce.pb.gov.br/dados-abertos-do-sagres-tcepb/
# Now checking url #998: http://www.dadosabertos.pe.gov.br/
# Now checking url #999: http://www.curitiba.pr.gov.br/dadosabertos/
# Now checking url #1000: http://data.rio/
# Now checking url #1001: http://portalgeo.pcrj.opendata.arcgis.com/
# Now checking url #1002: https://dados.portoalegre.rs.gov.br/
# Now checking url #1003: http://www.camara.sp.gov.br/transparencia/dados-abertos/
# Now checking url #1004: http://dados.mprs.mp.br/
# Now checking url #1005: http://transparencia.tce.sp.gov.br/
# Now checking url #1006: http://apidadosabertos.tce.rn.gov.br/
# Now checking url #1007: http://www.itabira.cam.mg.gov.br/dados-abertos
# Now checking url #1008: https://www.al.sp.gov.br/dados-abertos/
# Now checking url #1009: http://www.transparencia.anapolis.go.gov.br/transparencia/dadosAbertos.jsf
# Now checking url #1010: http://www.transparencia.mt.gov.br/downloads-de-bases
# Now checking url #1011: http://dados.pb.gov.br
# Now checking url #1012: http://transparencia.campinas.sp.gov.br/
# Now checking url #1013: https://dadosabertos.tce.mg.gov.br/
# Now checking url #1014: https://www.tce.pe.gov.br/internet/index.php/dados-abertos
# Now checking url #1015: http://geo.wa.gov
# Now checking url #1016: http://fiscal.wa.gov
# Now checking url #1017: http://dadosabertos.cl.df.gov.br/
# Now checking url #1018: https://stat.uz/en/
# Now checking url #1019: https://data.gov.uz/en
# Now checking url #1020: https://opendata.transport.nsw.gov.au/
# Now checking url #1021: http://www.agridata.tn/
# Now checking url #1022: http://www.opendata.ps/
# Now checking url #1023: https://portaldados.ppgau.uff.br/
# Now checking url #1024: https://www.stat.tj/en
# Now checking url #1025: https://dadosjusbr.org/
# Now checking url #1026: https://opendata.bratislava.sk
# Now checking url #1027: http://data.ctdata.org/
# Now checking url #1028: https://data.ci.newark.nj.us/
# Now checking url #1029: https://open.jacksonms.gov/
# Now checking url #1030: https://data.ca.gov/
# Now checking url #1031: https://datagate.snap4city.org/

# %%
stats_dict = {"datashades.info": {"original_url_list_length": len(shades), "count":0, "200":0}, 
              "dataportals.org": {"original_url_list_length": len(portals), "count":0, "200":0}, 
              "WPRDC": {"original_url_list_length": len(wprdc), "count":0, "200":0}}

for item in status_response:
    for items in stats_dict:
        if item['source'] == items:
            stats_dict[items]['count']+=1
            if item['status_code'] == 200:
                stats_dict[items]['200']+=1

for item in stats_dict:
    print(f'{item}: {stats_dict[item]}')
# Out:
# datashades.info: {'original_url_list_length': 516, 'count': 516, '200': 478}
# dataportals.org: {'original_url_list_length': 592, 'count': 510, '200': 419}
# WPRDC: {'original_url_list_length': 5, 'count': 5, '200': 5}

# %%
def ckan_status_show(passed_list):
    full_error_list = []
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
    x=0
    for item in passed_list:
        x+=1
        print(f'Now performing a status_show api call on site #{x}: {item["root_url"]}')
        try:
            response = requests.get(f'{item["source_url"]}/api/3/action/status_show', verify=False, headers=headers, timeout=120)
            content = json.loads(response.content)
            item["api_base_url"] = content["result"]["site_url"]
            item["site_title"] = content["result"]["site_title"]
            item["version"] = content["result"]["ckan_version"]
            item["locale"] = content["result"]["locale_default"]
            item["extensions"] = content["result"]["extensions"]
            item["source_or_base"] = "source"
        except Exception as e:
            try:
                response = requests.get(f'{item["base_url"]}/api/3/action/status_show', verify=False, headers=headers, timeout=120)
                content = json.loads(response.content)
                item["api_base_url"] = content["result"]["site_url"]
                item["site_title"] = content["result"]["site_title"]
                item["version"] = content["result"]["ckan_version"]
                item["locale"] = content["result"]["locale_default"]
                item["extensions"] = content["result"]["extensions"]
                item["source_or_base"] = "base"
            except Exception as e:
                error_list = [item["source_url"], (e.args)]
                full_error_list.append(error_list)
                pass
    return passed_list

status_show = ckan_status_show(status_response)
# Out:
# Now performing a status_show api call on site #1: data.cambridgeshireinsight.org.uk
# Now performing a status_show api call on site #2: africaopendata.org
# Now performing a status_show api call on site #3: govtech.in.th
# Now performing a status_show api call on site #4: opingogn.is
# Now performing a status_show api call on site #5: data.openpolice.ru
# Now performing a status_show api call on site #6: datos.agroindustria.gob.ar
# Now performing a status_show api call on site #7: dados.ufrn.br
# Now performing a status_show api call on site #8: data.odw.tw
# Now performing a status_show api call on site #9: data.gov.ie
# Now performing a status_show api call on site #10: geocatalogus.nl
# Now performing a status_show api call on site #11: dados.mda.gov.br
# Now performing a status_show api call on site #12: data.mariupolrada.gov.ua
# Now performing a status_show api call on site #13: dados.ufop.br
# Now performing a status_show api call on site #14: data.barrowbc.gov.uk
# Now performing a status_show api call on site #15: opendata.ugr.es
# Now performing a status_show api call on site #16: dados.uffs.edu.br
# Now performing a status_show api call on site #17: portal.igg.ac.mn
# Now performing a status_show api call on site #18: data.ed.gov
# Now performing a status_show api call on site #19: opendata.gov.mn
# Now performing a status_show api call on site #20: daten.rlp.de
# Now performing a status_show api call on site #21: data.gov.il
# Now performing a status_show api call on site #22: www.opengov-muenchen.de
# Now performing a status_show api call on site #23: dados.df.gov.br
# Now performing a status_show api call on site #24: ckan.jbrj.gov.br
# Now performing a status_show api call on site #25: data.bart.gov
# Now performing a status_show api call on site #26: opendata.plzen.eu
# Now performing a status_show api call on site #27: ckan.gsi.go.jp
# Now performing a status_show api call on site #28: data.nbco.gov.ie
# Now performing a status_show api call on site #29: data.gov.mk
# Now performing a status_show api call on site #30: data.imr.gov.ua
# Now performing a status_show api call on site #31: dados.cvm.gov.br
# Now performing a status_show api call on site #32: data.techno-science.ca
# Now performing a status_show api call on site #33: data.ok.gov
# Now performing a status_show api call on site #34: datos.santander.es
# Now performing a status_show api call on site #35: geodm.gr
# Now performing a status_show api call on site #36: gifu-opendata.pref.gifu.lg.jp
# Now performing a status_show api call on site #37: gisdata.mn.gov
# Now performing a status_show api call on site #38: opendata-ajuntament.barcelona.cat
# Now performing a status_show api call on site #39: dati.trentino.it
# Now performing a status_show api call on site #40: catalogue.data.wa.gov.au
# Now performing a status_show api call on site #41: flooddata.ses.nsw.gov.au
# Now performing a status_show api call on site #42: datos.jus.gob.ar
# Now performing a status_show api call on site #43: www.data.go.jp
# Now performing a status_show api call on site #44: dados.ons.org.br
# Now performing a status_show api call on site #45: datos.alcobendas.org
# Now performing a status_show api call on site #46: data.wonogirikab.go.id
# Now performing a status_show api call on site #47: data.pompanobeachfl.gov
# Now performing a status_show api call on site #48: 130.179.67.140
# Now performing a status_show api call on site #49: dados.cultura.gov.br
# Now performing a status_show api call on site #50: opendata.manresa.cat
# Now performing a status_show api call on site #51: www.fnde.gov.br
# Now performing a status_show api call on site #52: data.milwaukee.gov
# Now performing a status_show api call on site #53: www.data.qld.gov.au
# Now performing a status_show api call on site #54: unaids.fjelltopp.org
# Now performing a status_show api call on site #55: data.england.nhs.uk
# Now performing a status_show api call on site #56: data.nhm.ac.uk
# Now performing a status_show api call on site #57: data.cbwaterhub.ca
# Now performing a status_show api call on site #58: data.montreal.ca
# Now performing a status_show api call on site #59: www.civicdata.io
# Now performing a status_show api call on site #60: data.stadt-zuerich.ch
# Now performing a status_show api call on site #61: datos.transporte.gob.ar
# Now performing a status_show api call on site #62: datos.cultura.gob.ar
# Now performing a status_show api call on site #63: proyectoarde.org
# Now performing a status_show api call on site #64: www.data.brisbane.qld.gov.au
# Now performing a status_show api call on site #65: data.bris.ac.uk
# Now performing a status_show api call on site #66: catalog.industrie.gov.tn
# Now performing a status_show api call on site #67: hubofdata.ru
# Now performing a status_show api call on site #68: opendata.picturae.com
# Now performing a status_show api call on site #69: data.datahub.freightaustralia.gov.au
# Now performing a status_show api call on site #70: opendata.aragon.es
# Now performing a status_show api call on site #71: opendata.awt.be
# Now performing a status_show api call on site #72: opendata.bayern.de
# Now performing a status_show api call on site #73: opendata.leipzig.de
# Now performing a status_show api call on site #74: demo.ckan.org
# Now performing a status_show api call on site #75: datos.qroo.gob.mx
# Now performing a status_show api call on site #76: www.opendata.nhs.scot
# Now performing a status_show api call on site #77: datos.gob.cl
# Now performing a status_show api call on site #78: data.gov.au
# Now performing a status_show api call on site #79: data.gov.hr
# Now performing a status_show api call on site #80: agridata.tn
# Now performing a status_show api call on site #81: data.stat.pref.miyazaki.lg.jp
# Now performing a status_show api call on site #82: opendata.eol.org
# Now performing a status_show api call on site #83: dadosabertos.iftm.edu.br
# Now performing a status_show api call on site #84: opendata.hu
# Now performing a status_show api call on site #85: opendatabc.ca
# Now performing a status_show api call on site #86: liityntakatalogi.suomi.fi
# Now performing a status_show api call on site #87: opendata.adico.fr
# Now performing a status_show api call on site #88: data.waterpathogens.org
# Now performing a status_show api call on site #89: ckan.earlham.ac.uk
# Now performing a status_show api call on site #90: trouver.datasud.fr
# Now performing a status_show api call on site #91: data.vic.gov.au
# Now performing a status_show api call on site #92: linkeddatacatalog.dws.informatik.uni-mannheim.de
# Now performing a status_show api call on site #93: opendata.slavrada.gov.ua
# Now performing a status_show api call on site #94: data.yorkopendata.org
# Now performing a status_show api call on site #95: datasets.datos.mincyt.gob.ar
# Now performing a status_show api call on site #96: datacatalogue.gov.ie
# Now performing a status_show api call on site #97: opendata.br7.org.il
# Now performing a status_show api call on site #98: data.ontario.ca
# Now performing a status_show api call on site #99: open.stavanger.kommune.no
# Now performing a status_show api call on site #100: data.missouriepscor.org
# Now performing a status_show api call on site #101: www.pigma.org
# Now performing a status_show api call on site #102: datosabiertos.ayto-arganda.es
# Now performing a status_show api call on site #103: catalog-intaros.nersc.no
# Now performing a status_show api call on site #104: dados.antt.gov.br
# Now performing a status_show api call on site #105: opendata.camden.gov.uk
# Now performing a status_show api call on site #106: bermuda.io
# Now performing a status_show api call on site #107: arcticatlas.geobotany.org
# Now performing a status_show api call on site #108: datos.caf.com
# Now performing a status_show api call on site #109: datasets.fieldsofview.in
# Now performing a status_show api call on site #110: datos.gob.ar
# Now performing a status_show api call on site #111: ckan.dev.pdnd.italia.it
# Now performing a status_show api call on site #112: opendata.meerbusch.de
# Now performing a status_show api call on site #113: dados.ufpi.br
# Now performing a status_show api call on site #114: sprogteknologi.dk
# Now performing a status_show api call on site #115: catalogue.simocean.pt
# Now performing a status_show api call on site #116: datos.minfin.gob.gt
# Now performing a status_show api call on site #117: ckan.grassroots.tools
# Now performing a status_show api call on site #118: dadosabertos.bndes.gov.br
# Now performing a status_show api call on site #119: pacificdata.org
# Now performing a status_show api call on site #120: drdsi.jrc.ec.europa.eu
# Now performing a status_show api call on site #121: data.surrey.ca
# Now performing a status_show api call on site #122: dados.agricultura.gov.br
# Now performing a status_show api call on site #123: scoda.co.za
# Now performing a status_show api call on site #124: www.data.gov.my
# Now performing a status_show api call on site #125: data.ehealthireland.ie
# Now performing a status_show api call on site #126: ckan.fiware-testbed.jp
# Now performing a status_show api call on site #127: opendata.ozwillo.com
# Now performing a status_show api call on site #128: datenregister.berlin.de
# Now performing a status_show api call on site #129: staging.justicehub.in
# Now performing a status_show api call on site #130: donneesquebec.ca
# Now performing a status_show api call on site #131: opendata.comune.bari.it
# Now performing a status_show api call on site #132: dati.toscana.it
# Now performing a status_show api call on site #133: www.data.gv.at
# Now performing a status_show api call on site #134: opendata.imet.gr
# Now performing a status_show api call on site #135: catalog.data.gov
# Now performing a status_show api call on site #136: dados.recife.pe.gov.br
# Now performing a status_show api call on site #137: ckancc.g-location-server.site
# Now performing a status_show api call on site #138: data.gov.bf
# Now performing a status_show api call on site #139: data.msmt.cz
# Now performing a status_show api call on site #140: data.kk.dk
# Now performing a status_show api call on site #141: dadosabertos.antaq.gov.br
# Now performing a status_show api call on site #142: ckan.test-app.vwtelecom.com
# Now performing a status_show api call on site #143: ckanmtp.ymparisto.fi
# Now performing a status_show api call on site #144: apgc.awi.de
# Now performing a status_show api call on site #145: dados.contraosagrotoxicos.org
# Now performing a status_show api call on site #146: data.maintenance.org.au
# Now performing a status_show api call on site #147: ckan-d4s.d4science.org
# Now performing a status_show api call on site #148: dati.ustat.miur.it
# Now performing a status_show api call on site #149: demo.datashades.com
# Now performing a status_show api call on site #150: dati.comune.matera.it
# Now performing a status_show api call on site #151: dato.chequeado.com
# Now performing a status_show api call on site #152: knowledge.omaha.org.cn
# Now performing a status_show api call on site #153: data.open.guelph.ca
# Now performing a status_show api call on site #154: data.tegalkab.go.id
# Now performing a status_show api call on site #155: opendatastore.brussels
# Now performing a status_show api call on site #156: edx.netl.doe.gov
# Now performing a status_show api call on site #157: govdata.de
# Now performing a status_show api call on site #158: dataportal.geofyn.dk
# Now performing a status_show api call on site #159: canwin-datahub.ad.umanitoba.ca
# Now performing a status_show api call on site #160: data.vulekamali.gov.za
# Now performing a status_show api call on site #161: www.geo2france.fr
# Now performing a status_show api call on site #162: opendata.semarangkota.go.id
# Now performing a status_show api call on site #163: data.sba.gov
# Now performing a status_show api call on site #164: dados.ufes.br
# Now performing a status_show api call on site #165: data-test.toll.no
# Now performing a status_show api call on site #166: ckanviz.swige.unhcr.org
# Now performing a status_show api call on site #167: datos.gob.sv
# Now performing a status_show api call on site #168: dados.gov.br
# Now performing a status_show api call on site #169: dadosabertos.prefeitura.poa.br
# Now performing a status_show api call on site #170: opendata.mzcr.cz
# Now performing a status_show api call on site #171: b2find.eudat.eu
# Now performing a status_show api call on site #172: opendata.portdebarcelona.cat
# Now performing a status_show api call on site #173: dados.mg.gov.br
# Now performing a status_show api call on site #174: datos.techo.org
# Now performing a status_show api call on site #175: data.cityofboston.gov
# Now performing a status_show api call on site #176: opendata.ayto-caceres.es
# Now performing a status_show api call on site #177: datos.misiones.gov.ar
# Now performing a status_show api call on site #178: dados.ifsp.edu.br
# Now performing a status_show api call on site #179: www.eia.gov
# Now performing a status_show api call on site #180: dadosabertos.senado.gov.br
# Now performing a status_show api call on site #181: data.opendataportal.at
# Now performing a status_show api call on site #182: data.cityofdenton.com
# Now performing a status_show api call on site #183: data.zagreb.hr
# Now performing a status_show api call on site #184: ckan.project-hobbit.eu
# Now performing a status_show api call on site #185: ecaidata.org
# Now performing a status_show api call on site #186: geodata.gov.gr
# Now performing a status_show api call on site #187: avindata.ca
# Now performing a status_show api call on site #188: dados.ibict.br
# Now performing a status_show api call on site #189: data.aurin.org.au
# Now performing a status_show api call on site #190: beta.ukdataservice.ac.uk
# Now performing a status_show api call on site #191: dadosabertos.dataprev.gov.br
# Now performing a status_show api call on site #192: opendata.euroinfosicilia.it
# Now performing a status_show api call on site #193: datasets.catalogue.data.gov.dk
# Now performing a status_show api call on site #194: katalog.data.go.id
# Now performing a status_show api call on site #195: datapoa.com.br
# Now performing a status_show api call on site #196: poc-api.excise.go.th
# Now performing a status_show api call on site #197: usmart.io
# Now performing a status_show api call on site #198: hub.satudata.bappenas.go.id
# Now performing a status_show api call on site #199: ckan.pearlpv-cost.eu
# Now performing a status_show api call on site #200: ckan.africadatahub.org
# Now performing a status_show api call on site #201: oasishub.co
# Now performing a status_show api call on site #202: dados.ufpr.br
# Now performing a status_show api call on site #203: leedsdatamill.org
# Now performing a status_show api call on site #204: annuario.comune.fi.it
# Now performing a status_show api call on site #205: data.gov.md
# Now performing a status_show api call on site #206: opendata.penghu.gov.tw
# Now performing a status_show api call on site #207: datos.magyp.gob.ar
# Now performing a status_show api call on site #208: edu.mrpam.gov.mn
# Now performing a status_show api call on site #209: data.agglo-royan.fr
# Now performing a status_show api call on site #210: dadosabertos.unilab.edu.br
# Now performing a status_show api call on site #211: datos.do.magnet.cl
# Now performing a status_show api call on site #212: opendata.oorlogsbronnen.nl
# Now performing a status_show api call on site #213: dataplatformfiets.be
# Now performing a status_show api call on site #214: data.sa.gov.au
# Now performing a status_show api call on site #215: data.boston.gov
# Now performing a status_show api call on site #216: data.city.osaka.lg.jp
# Now performing a status_show api call on site #217: www.opendataphilly.org
# Now performing a status_show api call on site #218: coat.nina.no
# Now performing a status_show api call on site #219: data.houstontx.gov
# Now performing a status_show api call on site #220: data.glasgow.gov.uk
# Now performing a status_show api call on site #221: www.data.gov.ma
# Now performing a status_show api call on site #222: data.birminghamal.gov
# Now performing a status_show api call on site #223: dev.opencity.in
# Now performing a status_show api call on site #224: opendata.alcoi.org
# Now performing a status_show api call on site #225: openbaladiati.tn
# Now performing a status_show api call on site #226: data.illinois.gov
# Now performing a status_show api call on site #227: data.pkc.gov.uk
# Now performing a status_show api call on site #228: mggl-ckan-web.asifarm.it
# Now performing a status_show api call on site #229: www.ecaidata.org
# Now performing a status_show api call on site #230: data.qld.gov.au
# Now performing a status_show api call on site #231: dados.ufcspa.edu.br
# Now performing a status_show api call on site #232: nosdonnees.fr
# Now performing a status_show api call on site #233: transparencia.enargas.gov.ar
# Now performing a status_show api call on site #234: api.foodsecurityportal.org
# Now performing a status_show api call on site #235: ckan.pref.shizuoka.jp
# Now performing a status_show api call on site #236: radius.amplusdata.io
# Now performing a status_show api call on site #237: datosretc.mma.gob.cl
# Now performing a status_show api call on site #238: tpbs.igenco.co.th
# Now performing a status_show api call on site #239: data.gov.ua
# Now performing a status_show api call on site #240: data.vbgov.com
# Now performing a status_show api call on site #241: dati.mit.gov.it
# Now performing a status_show api call on site #242: ckan.cabi.org
# Now performing a status_show api call on site #243: www.donneesquebec.ca
# Now performing a status_show api call on site #244: opendatalecce.apposta.biz
# Now performing a status_show api call on site #245: podatki.gov.si
# Now performing a status_show api call on site #246: data.gov.sk
# Now performing a status_show api call on site #247: opendata.slavuta-mvk.gov.ua
# Now performing a status_show api call on site #248: data.depositar.io
# Now performing a status_show api call on site #249: data.pref.kyoto.lg.jp
# Now performing a status_show api call on site #250: ckan.seki.jx.org
# Now performing a status_show api call on site #251: data.pemalangkab.go.id
# Now performing a status_show api call on site #252: offenedaten.de
# Now performing a status_show api call on site #253: kod.brno.cz
# Now performing a status_show api call on site #254: opendata.caceres.es
# Now performing a status_show api call on site #255: datahub.io
# Now performing a status_show api call on site #256: bmckan.cpami.gov.tw
# Now performing a status_show api call on site #257: opendata.dev-vlaanderen.be
# Now performing a status_show api call on site #258: dartportal.leeds.ac.uk
# Now performing a status_show api call on site #259: data.nsw.gov.au
# Now performing a status_show api call on site #260: opendata.gov.je
# Now performing a status_show api call on site #261: dataportal.gov.tc
# Now performing a status_show api call on site #262: dados.ifrn.edu.br
# Now performing a status_show api call on site #263: data.open.guelph.ca.
# Now performing a status_show api call on site #264: www.tesourotransparente.gov.br
# Now performing a status_show api call on site #265: data.kalamazoocity.org
# Now performing a status_show api call on site #266: gis-hub.ca
# Now performing a status_show api call on site #267: datos.pami.org.ar
# Now performing a status_show api call on site #268: data.lexingtonky.gov
# Now performing a status_show api call on site #269: opendata.gov.cz
# Now performing a status_show api call on site #270: ballaratopendata.org.au
# Now performing a status_show api call on site #271: mobidata-bw.de
# Now performing a status_show api call on site #272: data.transport.tn
# Now performing a status_show api call on site #273: opendata.vlaanderen.be
# Now performing a status_show api call on site #274: datos.aytolalaguna.es
# Now performing a status_show api call on site #275: data.num.edu.mn
# Now performing a status_show api call on site #276: opendata.com.pk
# Now performing a status_show api call on site #277: data.gov.gr
# Now performing a status_show api call on site #278: opendata.wigan.gov.uk
# Now performing a status_show api call on site #279: danepubliczne.gov.pl
# Now performing a status_show api call on site #280: portal.ai-global.org
# Now performing a status_show api call on site #281: www.openculture.gov.tn
# Now performing a status_show api call on site #282: datos.yvera.gob.ar
# Now performing a status_show api call on site #283: dados.ifms.edu.br
# Now performing a status_show api call on site #284: datosabiertos.bogota.gov.co
# Now performing a status_show api call on site #285: data.gov.uk
# Now performing a status_show api call on site #286: data.uni-hannover.de
# Now performing a status_show api call on site #287: dadosjuventude.ibict.br
# Now performing a status_show api call on site #288: datosabiertos.rivasciudad.es
# Now performing a status_show api call on site #289: data.pekalongankota.go.id
# Now performing a status_show api call on site #290: opendata.city.moka.lg.jp
# Now performing a status_show api call on site #291: ckan.govdata.de
# Now performing a status_show api call on site #292: opendata.worcesterma.gov
# Now performing a status_show api call on site #293: data.hub.zamg.ac.at
# Now performing a status_show api call on site #294: taijiang.tw
# Now performing a status_show api call on site #295: data.purbalinggakab.go.id
# Now performing a status_show api call on site #296: data.birmingham.gov.uk
# Now performing a status_show api call on site #297: opendata.abbeville.fr
# Now performing a status_show api call on site #298: dados.fortaleza.ce.gov.br
# Now performing a status_show api call on site #299: opendatanepal.com
# Now performing a status_show api call on site #300: data.agriculturelittorale.fr
# Now performing a status_show api call on site #301: adr.unaids.org
# Now performing a status_show api call on site #302: data.biodiversity.be
# Now performing a status_show api call on site #303: dadosabertos.ifal.edu.br
# Now performing a status_show api call on site #304: catalogue.nextgeoss.eu
# Now performing a status_show api call on site #305: dataportal.eu-interact.org
# Now performing a status_show api call on site #306: www.datapoa.com.br
# Now performing a status_show api call on site #307: data.stirling.gov.uk
# Now performing a status_show api call on site #308: dados.natal.br
# Now performing a status_show api call on site #309: data-gov-ua.org
# Now performing a status_show api call on site #310: ckan.geonet-mrn.de
# Now performing a status_show api call on site #311: geoscience.data.qld.gov.au
# Now performing a status_show api call on site #312: openkg.cn
# Now performing a status_show api call on site #313: opendata.praha.eu
# Now performing a status_show api call on site #314: opendata.med.kg
# Now performing a status_show api call on site #315: opendata.mzp.cz
# Now performing a status_show api call on site #316: datos.cali.gov.co
# Now performing a status_show api call on site #317: data.gov.sg
# Now performing a status_show api call on site #318: data.smartdublin.ie
# Now performing a status_show api call on site #319: data.skeenasalmon.info
# Now performing a status_show api call on site #320: data.opendevelopmentmekong.net
# Now performing a status_show api call on site #321: ouvert.canada.ca
# Now performing a status_show api call on site #322: ckan.otevrenamesta.cz
# Now performing a status_show api call on site #323: data.overheid.nl
# Now performing a status_show api call on site #324: catalogue.cioos.ca
# Now performing a status_show api call on site #325: catalogue.ogsl.ca
# Now performing a status_show api call on site #326: rotterdamopendata.nl
# Now performing a status_show api call on site #327: dataportal.saeri.org
# Now performing a status_show api call on site #328: data.london.gov.uk
# Now performing a status_show api call on site #329: openbudgetsindia.org
# Now performing a status_show api call on site #330: publications.aberdeenshire.gov.uk
# Now performing a status_show api call on site #331: dados.ufsm.br
# Now performing a status_show api call on site #332: dados.ufrgs.br
# Now performing a status_show api call on site #333: dados.al.gov.br
# Now performing a status_show api call on site #334: datastore.landcareresearch.co.nz
# Now performing a status_show api call on site #335: dados.ufca.edu.br
# Now performing a status_show api call on site #336: dados.ifro.edu.br
# Now performing a status_show api call on site #337: data.bayanat.ae
# Now performing a status_show api call on site #338: library.atticawetlands.eu
# Now performing a status_show api call on site #339: data.city.yokohama.lg.jp
# Now performing a status_show api call on site #340: portal.opendata.dk
# Now performing a status_show api call on site #341: hidalgo1.man.poznan.pl
# Now performing a status_show api call on site #342: datos.mininterior.gob.ar
# Now performing a status_show api call on site #343: ckan.sansa.saeoss.org
# Now performing a status_show api call on site #344: datosabiertos.malaga.eu
# Now performing a status_show api call on site #345: healthquery.sh.cn
# Now performing a status_show api call on site #346: rdm.inesctec.pt
# Now performing a status_show api call on site #347: portal.merit.mn
# Now performing a status_show api call on site #348: portal.openbelgium.be
# Now performing a status_show api call on site #349: datos.salud.gob.ar
# Now performing a status_show api call on site #350: data.wprdc.org
# Now performing a status_show api call on site #351: data.whiterockcity.ca
# Now performing a status_show api call on site #352: data.tainan.gov.tw
# Now performing a status_show api call on site #353: hri.fi
# Now performing a status_show api call on site #354: opendata.aachen.de
# Now performing a status_show api call on site #355: scidm.nchc.org.tw
# Now performing a status_show api call on site #356: opendata.materaevents.it
# Now performing a status_show api call on site #357: data.salzburgerland.com
# Now performing a status_show api call on site #358: ckan.ev.openindustry.in
# Now performing a status_show api call on site #359: www.transparencia.mg.gov.br
# Now performing a status_show api call on site #360: data.opendata.durban
# Now performing a status_show api call on site #361: datango.infoculture.ru
# Now performing a status_show api call on site #362: data.brisbane.qld.gov.au
# Now performing a status_show api call on site #363: data.fingrid.fi
# Now performing a status_show api call on site #364: datosabiertos.mendoza.gov.ar
# Now performing a status_show api call on site #365: data.cilacapkab.go.id
# Now performing a status_show api call on site #366: data.gov.cz
# Now performing a status_show api call on site #367: datos.veracruzmunicipio.gob.mx
# Now performing a status_show api call on site #368: dados.prefeitura.sp.gov.br
# Now performing a status_show api call on site #369: data2.cerdi.edu.au
# Now performing a status_show api call on site #370: opendata.fortsmithar.gov
# Now performing a status_show api call on site #371: www.opendatani.gov.uk
# Now performing a status_show api call on site #372: data.ioos.us
# Now performing a status_show api call on site #373: opendata.e-land.gov.tw
# Now performing a status_show api call on site #374: playdrive-lb-4.ezylink.co
# Now performing a status_show api call on site #375: data.coat.no
# Now performing a status_show api call on site #376: dataplatform.knmi.nl
# Now performing a status_show api call on site #377: dadosabertos.ufersa.edu.br
# Now performing a status_show api call on site #378: ngodata.ru
# Now performing a status_show api call on site #379: opendata.sjgov.org
# Now performing a status_show api call on site #380: dados.ifrs.edu.br
# Now performing a status_show api call on site #381: transparencia.enargas.gob.ar
# Now performing a status_show api call on site #382: gardentasuna.errenteria.eus
# Now performing a status_show api call on site #383: data.acehselatankab.go.id
# Now performing a status_show api call on site #384: data.ecosis.org
# Now performing a status_show api call on site #385: www.nosdonnees.fr
# Now performing a status_show api call on site #386: www.opendata-hro.de
# Now performing a status_show api call on site #387: opendata.mmdecin.cz
# Now performing a status_show api call on site #388: data.buenosaires.gob.ar
# Now performing a status_show api call on site #389: data.opencolorado.org
# Now performing a status_show api call on site #390: iatiregistry.org
# Now performing a status_show api call on site #391: maps.mapaction.org
# Now performing a status_show api call on site #392: datasets.wri.org
# Now performing a status_show api call on site #393: test.data.ontario.ca
# Now performing a status_show api call on site #394: www.odata.org.il
# Now performing a status_show api call on site #395: resiliencedata.nfwf.org
# Now performing a status_show api call on site #396: data.balikpapan.go.id
# Now performing a status_show api call on site #397: opendata.muenchen.de
# Now performing a status_show api call on site #398: buildingamerica.openei.org
# Now performing a status_show api call on site #399: dados.rs.gov.br
# Now performing a status_show api call on site #400: pe.181.209.63.227.nip.io
# Now performing a status_show api call on site #401: www.data.vic.gov.au
# Now performing a status_show api call on site #402: data.mmr.cz
# Now performing a status_show api call on site #403: data.kcg.gov.tw
# Now performing a status_show api call on site #404: data.humdata.org
# Now performing a status_show api call on site #405: opendata.cabq.gov
# Now performing a status_show api call on site #406: ckan.opendatamalta.com
# Now performing a status_show api call on site #407: dados.ifsertao-pe.edu.br
# Now performing a status_show api call on site #408: dadosabertos.ifc.edu.br
# Now performing a status_show api call on site #409: web.transparencia.pe.gov.br
# Now performing a status_show api call on site #410: offenedaten.aachen.de
# Now performing a status_show api call on site #411: dados.ifmt.edu.br
# Now performing a status_show api call on site #412: data-portal.hpc.swin.edu.au
# Now performing a status_show api call on site #413: dataurbe.appcivico.com
# Now performing a status_show api call on site #414: data.sgm.ru
# Now performing a status_show api call on site #415: data.review.fao.org
# Now performing a status_show api call on site #416: datos.ambiente.gob.ar
# Now performing a status_show api call on site #417: www.wvcheckbook.gov
# Now performing a status_show api call on site #418: dados.ifsuldeminas.edu.br
# Now performing a status_show api call on site #419: opendata.hautsdefrance.fr
# Now performing a status_show api call on site #420: datasets.seed.nsw.gov.au
# Now performing a status_show api call on site #421: data.tn.gov
# Now performing a status_show api call on site #422: dados.tce.rs.gov.br
# Now performing a status_show api call on site #423: opendata.city-adm.lviv.ua
# Now performing a status_show api call on site #424: datar.noip.me
# Now performing a status_show api call on site #425: opendata.go.tz
# Now performing a status_show api call on site #426: digitalthailand.gistda.or.th
# Now performing a status_show api call on site #427: data.tampere.fi
# Now performing a status_show api call on site #428: catalogo.datosabiertos.gob.ec
# Now performing a status_show api call on site #429: dados.ana.gov.br
# Now performing a status_show api call on site #430: datosabiertos.fuengirola.es
# Now performing a status_show api call on site #431: opendata.swiss
# Now performing a status_show api call on site #432: ckan.pf-sapporo.jp
# Now performing a status_show api call on site #433: dadosabertos.bcb.gov.br
# Now performing a status_show api call on site #434: opendata.comune.re.it
# Now performing a status_show api call on site #435: datosabiertos.mercedes.gob.ar
# Now performing a status_show api call on site #436: dataut.vegvesen.no
# Now performing a status_show api call on site #437: dataportal.smartcityinnovation.eu
# Now performing a status_show api call on site #438: dadesobertes.salou.cat
# Now performing a status_show api call on site #439: bigdata-metadados.icict.fiocruz.br
# Now performing a status_show api call on site #440: dataworks.calderdale.gov.uk
# Now performing a status_show api call on site #441: data.gov.lv
# Now performing a status_show api call on site #442: datosestadistica.cba.gov.ar
# Now performing a status_show api call on site #443: datos.congresogto.gob.mx
# Now performing a status_show api call on site #444: opendatadafni.getmap.gr
# Now performing a status_show api call on site #445: docs.entsoe.eu
# Now performing a status_show api call on site #446: dati.arpae.it
# Now performing a status_show api call on site #447: dados.unifesspa.edu.br
# Now performing a status_show api call on site #448: dados.pbh.gov.br
# Now performing a status_show api call on site #449: odata.org.il
# Now performing a status_show api call on site #450: catalogue.data.gov.bc.ca
# Now performing a status_show api call on site #451: ck.govdata.gov.br
# Now performing a status_show api call on site #452: sprogressource.digst.govcloud.dk
# Now performing a status_show api call on site #453: datos.minem.gob.ar
# Now performing a status_show api call on site #454: claircitydata.cbs.nl
# Now performing a status_show api call on site #455: repository.participatorylab.org
# Now performing a status_show api call on site #456: dados.justica.gov.pt
# Now performing a status_show api call on site #457: data.gov.hk
# Now performing a status_show api call on site #458: data.amsterdam.nl
# Now performing a status_show api call on site #459: data.cdc.gov.tw
# Now performing a status_show api call on site #460: data.corkcity.ie
# Now performing a status_show api call on site #461: dadosabertos.ufma.br
# Now performing a status_show api call on site #462: datos.arsat.com.ar
# Now performing a status_show api call on site #463: data.mempawahkab.go.id
# Now performing a status_show api call on site #464: data.edincubator.eu
# Now performing a status_show api call on site #465: data.sanjoseca.gov
# Now performing a status_show api call on site #466: data.staging.sba.gov
# Now performing a status_show api call on site #467: data.investigatemidwest.org
# Now performing a status_show api call on site #468: datosabiertos.mineduc.gob.gt
# Now performing a status_show api call on site #469: data.gov.sa
# Now performing a status_show api call on site #470: daten.buergernetz.bz.it
# Now performing a status_show api call on site #471: data.env.go.jp
# Now performing a status_show api call on site #472: data.nrri.umn.edu
# Now performing a status_show api call on site #473: data.europa.eu
# Now performing a status_show api call on site #474: dadosabertos.ibama.gov.br
# Now performing a status_show api call on site #475: www.dados.univasf.edu.br
# Now performing a status_show api call on site #476: transparencia.alhaurindelatorre.es
# Now performing a status_show api call on site #477: dados.ufrr.br
# Now performing a status_show api call on site #478: data.openstate.eu
# Now performing a status_show api call on site #479: phoenixopendata.com
# Now performing a status_show api call on site #480: opendata.lisra.jp
# Now performing a status_show api call on site #481: bernco.civicdashboards.com
# Now performing a status_show api call on site #482: datamx.io
# Now performing a status_show api call on site #483: transparenz.karlsruhe.de
# Now performing a status_show api call on site #484: data.gov.ro
# Now performing a status_show api call on site #485: transportdata.be
# Now performing a status_show api call on site #486: opendata.meteo.tn
# Now performing a status_show api call on site #487: dataportal.smartme.io
# Now performing a status_show api call on site #488: data.aberdeencity.gov.uk
# Now performing a status_show api call on site #489: catalogo.governoaberto.sp.gov.br
# Now performing a status_show api call on site #490: dataportal.cps.chula.ac.th
# Now performing a status_show api call on site #491: www.odaa.dk
# Now performing a status_show api call on site #492: data.ottawa.ca
# Now performing a status_show api call on site #493: data.pontianakkota.go.id
# Now performing a status_show api call on site #494: datenportal.pado-projekt.de
# Now performing a status_show api call on site #495: www.donostia.eus
# Now performing a status_show api call on site #496: data.sanantonio.gov
# Now performing a status_show api call on site #497: opendata.kp.gov.pk
# Now performing a status_show api call on site #498: data.edinburghopendata.info
# Now performing a status_show api call on site #499: salforddataquay.uk
# Now performing a status_show api call on site #500: basedosdados.org
# Now performing a status_show api call on site #501: opendata.nhsbsa.net
# Now performing a status_show api call on site #502: dadosabertos.ufms.br
# Now performing a status_show api call on site #503: dadosabertos.capes.gov.br
# Now performing a status_show api call on site #504: opendata.angus.gov.uk
# Now performing a status_show api call on site #505: open.canada.ca
# Now performing a status_show api call on site #506: data.doi.gov
# Now performing a status_show api call on site #507: offenedaten.frankfurt.de
# Now performing a status_show api call on site #508: dados.ufpel.edu.br
# Now performing a status_show api call on site #509: finrahoitus.fi
# Now performing a status_show api call on site #510: www.basedosdados.org
# Now performing a status_show api call on site #511: datospublicos.org
# Now performing a status_show api call on site #512: avoindata.fi
# Now performing a status_show api call on site #513: data.treasury.ri.gov
# Now performing a status_show api call on site #514: dados.mma.gov.br
# Now performing a status_show api call on site #515: donnees.ville.montreal.qc.ca
# Now performing a status_show api call on site #516: www.transparencia.dadosabertos.mg.gov.br
# Now performing a status_show api call on site #517: www.a2gov.org
# Now performing a status_show api call on site #518: acikveri.sahinbey.bel.tr
# Now performing a status_show api call on site #519: opendata.tarragona.cat
# Now performing a status_show api call on site #520: opendata.terrassa.cat
# Now performing a status_show api call on site #521: open.alabama.gov
# Now performing a status_show api call on site #522: open.data.al
# Now performing a status_show api call on site #523: open.alberta.ca
# Now performing a status_show api call on site #524: algeria.opendataforafrica.org
# Now performing a status_show api call on site #525: www.alkmaar.nl
# Now performing a status_show api call on site #526: www.allerdale.gov.uk
# Now performing a status_show api call on site #527: www.gisdro.nl
# Now performing a status_show api call on site #528: www.amsterdamopendata.nl
# Now performing a status_show api call on site #529: www.juntadeandalucia.es
# Now performing a status_show api call on site #530: data.angers.fr
# Now performing a status_show api call on site #531: arvada.org
# Now performing a status_show api call on site #532: risp.asturias.es
# Now performing a status_show api call on site #533: data.vorarlberg.gv.at
# Now performing a status_show api call on site #534: www1.data.antarctica.gov.au
# Now performing a status_show api call on site #535: ada.edu.au
# Now performing a status_show api call on site #536: aihw.gov.au
# Now performing a status_show api call on site #537: observa.gijon.es
# Now performing a status_show api call on site #538: datos.madrid.es
# Now performing a status_show api call on site #539: badalona.cat
# Now performing a status_show api call on site #540: www.bahrain.bh
# Now performing a status_show api call on site #541: www.data.gov.bh
# Now performing a status_show api call on site #542: www.banffopendata.ca
# Now performing a status_show api call on site #543: data.bathhacked.org
# Now performing a status_show api call on site #544: www.bcn.cat
# Now performing a status_show api call on site #545: www.bjdata.gov.cn
# Now performing a status_show api call on site #546: daten.berlin.de
# Now performing a status_show api call on site #547: www.bilbao.net
# Now performing a status_show api call on site #548: www.birmingham.gov.uk
# Now performing a status_show api call on site #549: www.bizstats.co.uk
# Now performing a status_show api call on site #550: dati.comune.bologna.it
# Now performing a status_show api call on site #551: hubmaps1.cityofboston.gov
# Now performing a status_show api call on site #552: data.visitprovence.com
# Now performing a status_show api call on site #553: www.brampton.ca
# Now performing a status_show api call on site #554: opengov.brandon.ca
# Now performing a status_show api call on site #555: opendata.bristol.gov.uk
# Now performing a status_show api call on site #556: budget.gov.ru
# Now performing a status_show api call on site #557: cms.burlington.ca
# Now performing a status_show api call on site #558: opendata.busan.go.kr
# Now performing a status_show api call on site #559: www.data.ca.gov
# Now performing a status_show api call on site #560: opendata.gov.nl.ca
# Now performing a status_show api call on site #561: app.kitchener.ca
# Now performing a status_show api call on site #562: climate.calcommons.org
# Now performing a status_show api call on site #563: www.caib.es
# Now performing a status_show api call on site #564: cityonline.calgary.ca
# Now performing a status_show api call on site #565: chhs.data.ca.gov
# Now performing a status_show api call on site #566: opendata.cambridgeshireinsight.org.uk
# Now performing a status_show api call on site #567: www.linkedopencamera.it
# Now performing a status_show api call on site #568: cameroon.opendataforafrica.org
# Now performing a status_show api call on site #569: caboverde.opendataforafrica.org
# Now performing a status_show api call on site #570: centraldedados.pt
# Now performing a status_show api call on site #571: dati.camera.it
# Now performing a status_show api call on site #572: www.chatham-kent.ca
# Now performing a status_show api call on site #573: data.chattlibrary.org
# Now performing a status_show api call on site #574: data.cityofchicago.org
# Now performing a status_show api call on site #575: datos.bcn.cl
# Now performing a status_show api call on site #576: www.consejotransparencia.cl
# Now performing a status_show api call on site #577: www.chilliwack.com
# Now performing a status_show api call on site #578: govinfo.nlc.gov.cn
# Now performing a status_show api call on site #579: opendurham.nc.gov
# Now performing a status_show api call on site #580: data.honolulu.gov
# Now performing a status_show api call on site #581: data-avl.opendata.arcgis.com
# Now performing a status_show api call on site #582: data.austintexas.gov
# Now performing a status_show api call on site #583: data.brla.gov
# Now performing a status_show api call on site #584: bouldercolorado.gov
# Now performing a status_show api call on site #585: data.culvercity.org
# Now performing a status_show api call on site #586: data.detroitmi.gov
# Now performing a status_show api call on site #587: data.grcity.us
# Now performing a status_show api call on site #588: data.kcmo.org
# Now performing a status_show api call on site #589: opendata.lasvegasnevada.gov
# Now performing a status_show api call on site #590: data.lacity.org
# Now performing a status_show api call on site #591: data.cityofmadison.com
# Now performing a status_show api call on site #592: opendata.minneapolismn.gov
# Now performing a status_show api call on site #593: data.cityofpaloalto.org
# Now performing a status_show api call on site #594: data.cityofpasadena.net
# Now performing a status_show api call on site #595: data.providenceri.gov
# Now performing a status_show api call on site #596: data.richmondgov.com
# Now performing a status_show api call on site #597: data.cityofsacramento.org
# Now performing a status_show api call on site #598: data.santa-clarita.com
# Now performing a status_show api call on site #599: data.smgov.net
# Now performing a status_show api call on site #600: opendata.waterloo.ca
# Now performing a status_show api call on site #601: data.weho.org
# Now performing a status_show api call on site #602: www.cityscale.com.ua
# Now performing a status_show api call on site #603: www.citywindsor.ca
# Now performing a status_show api call on site #604: www.civicapps.org
# Now performing a status_show api call on site #605: ie.ckan.net
# Now performing a status_show api call on site #606: br.ckan.net
# Now performing a status_show api call on site #607: it.ckan.net
# Now performing a status_show api call on site #608: rs.ckan.net
# Now performing a status_show api call on site #609: datos.codeandomexico.org
# Now performing a status_show api call on site #610: www.colorado.gov
# Now performing a status_show api call on site #611: www.comune.palermo.it
# Now performing a status_show api call on site #612: dati.comune.milano.it
# Now performing a status_show api call on site #613: dati.comune.roma.it
# Now performing a status_show api call on site #614: transparency.ct.gov
# Now performing a status_show api call on site #615: data.cookcountyil.gov
# Now performing a status_show api call on site #616: www.opendatacordoba.com
# Now performing a status_show api call on site #617: www.criik.com
# Now performing a status_show api call on site #618: data.csiro.au
# Now performing a status_show api call on site #619: data.lacub.fr
# Now performing a status_show api call on site #620: cz.ckan.net
# Now performing a status_show api call on site #621: arenysdemunt.smartgovs.info
# Now performing a status_show api call on site #622: dados.novohamburgo.rs.gov.br
# Now performing a status_show api call on site #623: data.daejeon.go.kr
# Now performing a status_show api call on site #624: zwgk.dl.gov.cn
# Now performing a status_show api call on site #625: www.dallasopendata.com
# Now performing a status_show api call on site #626: www.open.canada.ca
# Now performing a status_show api call on site #627: www.data.go.kr
# Now performing a status_show api call on site #628: www.data.gov
# Now performing a status_show api call on site #629: data.mos.ru
# Now performing a status_show api call on site #630: www.gov.hk
# Now performing a status_show api call on site #631: data.seattle.gov
# Now performing a status_show api call on site #632: www.datosabiertos.jcyl.es
# Now performing a status_show api call on site #633: data.gv.at
# Now performing a status_show api call on site #634: data.linz.gv.at
# Now performing a status_show api call on site #635: opendata.admin.ch
# Now performing a status_show api call on site #636: data.civicinfo.ca
# Now performing a status_show api call on site #637: data.colorado.gov
# Now performing a status_show api call on site #638: abertos.xunta.es
# Now performing a status_show api call on site #639: data.go.jp
# Now performing a status_show api call on site #640: data.go.th
# Now performing a status_show api call on site #641: www.data.gouv.fr
# Now performing a status_show api call on site #642: data.gov.ph
# Now performing a status_show api call on site #643: data.gov.tw
# Now performing a status_show api call on site #644: data.hartford.gov
# Now performing a status_show api call on site #645: data.lincoln.ac.uk
# Now performing a status_show api call on site #646: datameti.go.jp
# Now performing a status_show api call on site #647: data.norge.no
# Now performing a status_show api call on site #648: www.data-publica.com
# Now performing a status_show api call on site #649: data.ukmin.lt
# Now performing a status_show api call on site #650: data.ulm.de
# Now performing a status_show api call on site #651: data.act.gov.au
# Now performing a status_show api call on site #652: datacatalogs.org
# Now performing a status_show api call on site #653: www.data.ug
# Now performing a status_show api call on site #654: www.datagm.org.uk
# Now performing a status_show api call on site #655: datagov.ru
# Now performing a status_show api call on site #656: datakilder.no
# Now performing a status_show api call on site #657: datalocale.fr
# Now performing a status_show api call on site #658: datasf.org
# Now performing a status_show api call on site #659: www.datashanghai.gov.cn
# Now performing a status_show api call on site #660: opendata.service-bw.de
# Now performing a status_show api call on site #661: www.daten.bremen.de
# Now performing a status_show api call on site #662: dati.veneto.it
# Now performing a status_show api call on site #663: dati.emilia-romagna.it
# Now performing a status_show api call on site #664: dati.gov.it
# Now performing a status_show api call on site #665: www.dati.lombardia.it
# Now performing a status_show api call on site #666: www.datiopen.it
# Now performing a status_show api call on site #667: www.datos.misiones.gov.ar
# Now performing a status_show api call on site #668: datosabiertos.munlima.gob.pe
# Now performing a status_show api call on site #669: catalogodatos.gub.uy
# ...
# Now performing a status_show api call on site #811: www.offenes-jena.de
# Now performing a status_show api call on site #812: www.mo.gov
# Now performing a status_show api call on site #813: www.floridahasarighttoknow.com
# Now performing a status_show api call on site #814: www.rdos.bc.ca
# Now performing a status_show api call on site #815: www.data.gov.om
# Now performing a status_show api call on site #816: www.ost.pt
# Now performing a status_show api call on site #817: www.ontario.ca
# Now performing a status_show api call on site #818: www.opendatahub.it
# Now performing a status_show api call on site #819: www.opendata.tw
# Now performing a status_show api call on site #820: www.comune.trento.it
# Now performing a status_show api call on site #821: www.saudi.gov.sa
# Now performing a status_show api call on site #822: data.wien.gv.at
# Now performing a status_show api call on site #823: www.tn.gov
# Now performing a status_show api call on site #824: data.ny.gov
# Now performing a status_show api call on site #825: cat.open.org.nz
# Now performing a status_show api call on site #826: data.openva.com
# Now performing a status_show api call on site #827: opendata.antwerpen.be
# Now performing a status_show api call on site #828: www.datos.gov.co
# Now performing a status_show api call on site #829: dati.comune.firenze.it
# Now performing a status_show api call on site #830: opendataforafrica.org
# Now performing a status_show api call on site #831: opendatakosovo.org
# Now performing a status_show api call on site #832: sierraleone.opendataforafrica.org
# Now performing a status_show api call on site #833: opendata.gov.sl
# Now performing a status_show api call on site #834: catalog.opendata.in.th
# Now performing a status_show api call on site #835: www.opendevelopmentcambodia.net
# Now performing a status_show api call on site #836: www.openkent.org.uk
# Now performing a status_show api call on site #837: data.raleighnc.gov
# Now performing a status_show api call on site #838: open.stockholm.se
# Now performing a status_show api call on site #839: www.openumea.se
# Now performing a status_show api call on site #840: openaid.se
# Now performing a status_show api call on site #841: data.baltimorecity.gov
# Now performing a status_show api call on site #842: opendata.enschede.nl
# Now performing a status_show api call on site #843: www.opendata.go.ke
# Now performing a status_show api call on site #844: opendata.bonn.de
# Now performing a status_show api call on site #845: opendata.brussel.be
# Now performing a status_show api call on site #846: www.opendata.hu
# Now performing a status_show api call on site #847: opendata.lv
# Now performing a status_show api call on site #848: www.opendatabc.ca
# Now performing a status_show api call on site #849: www.manchester.gov.uk
# Now performing a status_show api call on site #850: www.opendataterritorioenna.it
# Now performing a status_show api call on site #851: opendoor.ky.gov
# Now performing a status_show api call on site #852: en.openei.org
# Now performing a status_show api call on site #853: opengov.es
# Now performing a status_show api call on site #854: www.opengov.se
# Now performing a status_show api call on site #855: opengovdata.ru
# Now performing a status_show api call on site #856: open.nrw
# Now performing a status_show api call on site #857: www.openstreetmap.org
# Now performing a status_show api call on site #858: oppnadata.se
# Now performing a status_show api call on site #859: www.orebro.se
# Now performing a status_show api call on site #860: data.oregon.gov
# Now performing a status_show api call on site #861: www.os.amsterdam.nl
# Now performing a status_show api call on site #862: www.ouka.fi
# Now performing a status_show api call on site #863: cartolleida.paeria.es
# Now performing a status_show api call on site #864: pamplona.es
# Now performing a status_show api call on site #865: opendata.paris.fr
# Now performing a status_show api call on site #866: www.comune.pv.it
# Now performing a status_show api call on site #867: picandmix.org.uk
# Now performing a status_show api call on site #868: www.dati.piemonte.it
# Now performing a status_show api call on site #869: opendata.jccm.es
# Now performing a status_show api call on site #870: www.despesapublica.com
# Now performing a status_show api call on site #871: princegeorge.ca
# Now performing a status_show api call on site #872: opendata.provincia.lucca.it
# Now performing a status_show api call on site #873: www.opendata.provincia.roma.it
# Now performing a status_show api call on site #874: www.dados.gov.pt
# Now performing a status_show api call on site #875: pub.uni-bielefeld.de
# Now performing a status_show api call on site #876: www.infomex.org.mx
# Now performing a status_show api call on site #877: publicdata.belgium.be
# Now performing a status_show api call on site #878: publicdata.eu
# Now performing a status_show api call on site #879: www.dati.puglia.it
# Now performing a status_show api call on site #880: data.gouv.qc.ca
# Now performing a status_show api call on site #881: qldspatial.information.qld.gov.au
# Now performing a status_show api call on site #882: donnees.ville.quebec.qc.ca
# Now performing a status_show api call on site #883: rcongo.opendataforafrica.org
# Now performing a status_show api call on site #884: www.recovery.gov
# Now performing a status_show api call on site #885: data.reddeer.ca
# Now performing a status_show api call on site #886: data.redbridge.gov.uk
# Now performing a status_show api call on site #887: www.regina.ca
# Now performing a status_show api call on site #888: www.york.ca
# Now performing a status_show api call on site #889: opendata.peelregion.ca
# Now performing a status_show api call on site #890: www.regionofwaterloo.ca
# Now performing a status_show api call on site #891: www.data.rennes-metropole.fr
# Now performing a status_show api call on site #892: researchdata.ands.org.au
# Now performing a status_show api call on site #893: www.ri.gov
# Now performing a status_show api call on site #894: www.opendata.larochelle.fr
# Now performing a status_show api call on site #895: www.rotterdamopendata.nl
# Now performing a status_show api call on site #896: rwanda.opendataforafrica.org
# Now performing a status_show api call on site #897: www.saanich.ca
# Now performing a status_show api call on site #898: www.salford.gov.uk
# Now performing a status_show api call on site #899: sdappschallenge.com
# Now performing a status_show api call on site #900: data.cityofsantacruz.com
# Now performing a status_show api call on site #901: www.opendata71.fr
# Now performing a status_show api call on site #902: www.sardegnageoportale.it
# Now performing a status_show api call on site #903: opendata-saskatoon.cloudapp.net
# Now performing a status_show api call on site #904: data.sejong.go.kr
# Now performing a status_show api call on site #905: www.semic.eu
# Now performing a status_show api call on site #906: dati.senato.it
# Now performing a status_show api call on site #907: senegal.opendataforafrica.org
# Now performing a status_show api call on site #908: data.seoul.go.kr
# Now performing a status_show api call on site #909: donnees.ville.sherbrooke.qc.ca
# Now performing a status_show api call on site #910: slip.landgate.wa.gov.au
# Now performing a status_show api call on site #911: open.gsnd.net
# Now performing a status_show api call on site #912: data.jeonnam.go.kr
# Now performing a status_show api call on site #913: web1.capetown.gov.za
# Now performing a status_show api call on site #914: municipalmoney.gov.za
# Now performing a status_show api call on site #915: municipaldata.treasury.gov.za
# Now performing a status_show api call on site #916: southafrica.opendataforafrica.org
# Now performing a status_show api call on site #917: vulekamali.gov.za
# Now performing a status_show api call on site #918: southsudan.opendataforafrica.org
# Now performing a status_show api call on site #919: datos.gob.es
# Now performing a status_show api call on site #920: data.sunshinecoast.qld.gov.au
# Now performing a status_show api call on site #921: www.statcentral.ie
# Now performing a status_show api call on site #922: www.nebraska.gov
# Now performing a status_show api call on site #923: data.wa.gov
# Now performing a status_show api call on site #924: www.strathcona.ca
# Now performing a status_show api call on site #925: data.suomi.fi
# Now performing a status_show api call on site #926: www.surrey.ca
# Now performing a status_show api call on site #927: www.sutton.gov.uk
# Now performing a status_show api call on site #928: data.taichung.gov.tw
# Now performing a status_show api call on site #929: tampere.fi
# Now performing a status_show api call on site #930: tanzania.opendataforafrica.org
# Now performing a status_show api call on site #931: www.texas.gov
# Now performing a status_show api call on site #932: www.texastransparency.org
# Now performing a status_show api call on site #933: data.pm.go.th
# Now performing a status_show api call on site #934: www.thunderbay.ca
# Now performing a status_show api call on site #935: data.tirol.gv.at
# Now performing a status_show api call on site #936: www.tol.ca
# Now performing a status_show api call on site #937: www.comune.torino.it
# Now performing a status_show api call on site #938: www.toronto.ca
# Now performing a status_show api call on site #939: data.grandtoulouse.fr
# Now performing a status_show api call on site #940: www.trafford.gov.uk
# Now performing a status_show api call on site #941: www.turkstat.gov.tr
# Now performing a status_show api call on site #942: tunisia.opendataforafrica.org
# Now performing a status_show api call on site #943: paikkatietokeskus.lounaispaikka.fi
# Now performing a status_show api call on site #944: www.government.ae
# Now performing a status_show api call on site #945: data.ulsan.go.kr
# Now performing a status_show api call on site #946: open.unhabitat.org
# Now performing a status_show api call on site #947: www.undata-api.org
# Now performing a status_show api call on site #948: servizi.comune.cesena.fc.it
# Now performing a status_show api call on site #949: data.ox.ac.uk
# Now performing a status_show api call on site #950: data.southampton.ac.uk
# Now performing a status_show api call on site #951: enforcedata.dol.gov
# Now performing a status_show api call on site #952: usaspending.gov
# Now performing a status_show api call on site #953: www.utah.gov
# Now performing a status_show api call on site #954: data.vancouver.ca
# Now performing a status_show api call on site #955: dati.venezia.it
# Now performing a status_show api call on site #956: www.vernon.ca
# Now performing a status_show api call on site #957: vicroadsopendata.vicroadsmaps.opendata.arcgis.com
# Now performing a status_show api call on site #958: www.victoria.ca
# Now performing a status_show api call on site #959: opendata.bordeaux.fr
# Now performing a status_show api call on site #960: datapoint.apa.virginia.gov
# Now performing a status_show api call on site #961: opendata.warwickshire.gov.uk
# Now performing a status_show api call on site #962: www.welland.ca
# Now performing a status_show api call on site #963: data.wa.gov.au
# Now performing a status_show api call on site #964: data.whitehorse.ca
# Now performing a status_show api call on site #965: data.winnipeg.ca
# Now performing a status_show api call on site #966: winnipegelection.ca
# Now performing a status_show api call on site #967: developer.worldbank.org
# Now performing a status_show api call on site #968: www.wyre.gov.uk
# Now performing a status_show api call on site #969: zambia.opendataforafrica.org
# Now performing a status_show api call on site #970: datos.zaragoza.es
# Now performing a status_show api call on site #971: zimbabwe.opendataforafrica.org
# Now performing a status_show api call on site #972: opendata.government.bg
# Now performing a status_show api call on site #973: data.hawaii.gov
# Now performing a status_show api call on site #974: openaq.org
# Now performing a status_show api call on site #975: geoinfo.msl.mt.gov
# Now performing a status_show api call on site #976: data-mtfwp.opendata.arcgis.com
# Now performing a status_show api call on site #977: github.com
# Now performing a status_show api call on site #978: www.dataplatform.nl
# Now performing a status_show api call on site #979: data.bandaacehkota.go.id
# Now performing a status_show api call on site #980: geo.gob.bo
# Now performing a status_show api call on site #981: data.telangana.gov.in
# Now performing a status_show api call on site #982: data.g0vhk.io
# Now performing a status_show api call on site #983: www.geoguyane.fr
# Now performing a status_show api call on site #984: www.otvorenipodatoci.gov.mk
# Now performing a status_show api call on site #985: armstat.am
# Now performing a status_show api call on site #986: data.gov.rs
# Now performing a status_show api call on site #987: data.linz.govt.nz
# Now performing a status_show api call on site #988: www.lincolnshire.gov.uk
# Now performing a status_show api call on site #989: opendata.tel-aviv.gov.il
# Now performing a status_show api call on site #990: data.culturecommunication.gouv.fr
# Now performing a status_show api call on site #991: nepalmap.org
# Now performing a status_show api call on site #992: dadosabertos.camara.leg.br
# Now performing a status_show api call on site #993: api.tcm.ce.gov.br
# Now performing a status_show api call on site #994: transparencia.es.gov.br
# Now performing a status_show api call on site #995: www.transparencia.go.gov.br
# Now performing a status_show api call on site #996: dadosabertos.almg.gov.br
# Now performing a status_show api call on site #997: portal.tce.pb.gov.br
# Now performing a status_show api call on site #998: www.dadosabertos.pe.gov.br
# Now performing a status_show api call on site #999: www.curitiba.pr.gov.br
# Now performing a status_show api call on site #1000: data.rio
# Now performing a status_show api call on site #1001: portalgeo.pcrj.opendata.arcgis.com
# Now performing a status_show api call on site #1002: dados.portoalegre.rs.gov.br
# Now performing a status_show api call on site #1003: www.camara.sp.gov.br
# Now performing a status_show api call on site #1004: dados.mprs.mp.br
# Now performing a status_show api call on site #1005: transparencia.tce.sp.gov.br
# Now performing a status_show api call on site #1006: apidadosabertos.tce.rn.gov.br
# Now performing a status_show api call on site #1007: www.itabira.cam.mg.gov.br
# Now performing a status_show api call on site #1008: www.al.sp.gov.br
# Now performing a status_show api call on site #1009: www.transparencia.anapolis.go.gov.br
# Now performing a status_show api call on site #1010: www.transparencia.mt.gov.br
# Now performing a status_show api call on site #1011: dados.pb.gov.br
# Now performing a status_show api call on site #1012: transparencia.campinas.sp.gov.br
# Now performing a status_show api call on site #1013: dadosabertos.tce.mg.gov.br
# Now performing a status_show api call on site #1014: www.tce.pe.gov.br
# Now performing a status_show api call on site #1015: geo.wa.gov
# Now performing a status_show api call on site #1016: fiscal.wa.gov
# Now performing a status_show api call on site #1017: dadosabertos.cl.df.gov.br
# Now performing a status_show api call on site #1018: stat.uz
# Now performing a status_show api call on site #1019: data.gov.uz
# Now performing a status_show api call on site #1020: opendata.transport.nsw.gov.au
# Now performing a status_show api call on site #1021: www.agridata.tn
# Now performing a status_show api call on site #1022: www.opendata.ps
# Now performing a status_show api call on site #1023: portaldados.ppgau.uff.br
# Now performing a status_show api call on site #1024: www.stat.tj
# Now performing a status_show api call on site #1025: dadosjusbr.org
# Now performing a status_show api call on site #1026: opendata.bratislava.sk
# Now performing a status_show api call on site #1027: data.ctdata.org
# Now performing a status_show api call on site #1028: data.ci.newark.nj.us
# Now performing a status_show api call on site #1029: open.jacksonms.gov
# Now performing a status_show api call on site #1030: data.ca.gov
# Now performing a status_show api call on site #1031: datagate.snap4city.org

# %%
def ckan_all_other_functions(passed_list):
    full_error_list_packages = []
    full_error_list_orgs = []
    full_error_list_tags = []
    full_error_list_dates = []
    full_error_list_new_dates = []
    x=0
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
    api_calls = ['package_list', 'tag_list', 'organization_list']
    def api_check(dict_to_check, url_category, api_call):
        url = f'{dict_to_check[url_category]}/api/3/action/{api_call}'
        response = requests.get(url, verify=False, headers=headers, timeout=120)
        content = json.loads(response.content)
        dict_to_check[f"{api_call}_count"] = len(content["result"])
        dict_to_check[f"{api_call}_source_base_or_apibase"] = url_category
        return dict_to_check

    def date_check(dict_to_check, url_category, current_best_metadata_date):
        url = f'{dict_to_check[url_category]}/api/3/action/current_package_list_with_resources?limit=2000000'
        response = requests.get(url, verify=False, headers=headers, timeout=120)
        content = json.loads(response.content)
        for items in content["result"]:
            metadata_creation_date = items["metadata_created"]
            m_c_d = parser.parse(metadata_creation_date)
            if m_c_d < current_best_metadata_date:
                current_best_metadata_date = m_c_d
            else:
                pass
        item["oldest_metadata_created_date"] = current_best_metadata_date
        most_recent_update_date = content["result"][0]["metadata_modified"]
        item["most_recent_update_date"] = parser.parse(most_recent_update_date)
        item["dates_source_base_or_apibase"] = url_category
        return dict_to_check

    for item in passed_list:
        x+=1
        print(f'Now performing additional API calls on site #{x}: {item["root_url"]}')
        current_best_metadata_date = datetime.now()
        for call in api_calls:
            try:
                api_check(item, "source_url", call)
            except Exception as e:
                try:
                    api_check(item, "base_url", call)
                except Exception as e:
                    try:
                        api_check(item, "api_base_url", call)
                    except Exception as e:
                        error_list = [item["source_url"], (e.args)]
                        full_error_list_packages.append(error_list)
                        pass
        try:
            date_check(item, "source_url", current_best_metadata_date)
        except Exception as e:
            try:
                date_check(item, "base_url", current_best_metadata_date)
            except Exception as e:
                try:
                    date_check(item, "api_base_url", current_best_metadata_date)
                except Exception as e:
                    error_list = [item["source_url"], (e.args)]
                    full_error_list_dates.append(error_list)
    return passed_list

all_requests_made = ckan_all_other_functions(status_show)
# Out:
# Now performing additional API calls on site #1: data.cambridgeshireinsight.org.uk
# Now performing additional API calls on site #2: africaopendata.org
# Now performing additional API calls on site #3: govtech.in.th
# Now performing additional API calls on site #4: opingogn.is
# Now performing additional API calls on site #5: data.openpolice.ru
# Now performing additional API calls on site #6: datos.agroindustria.gob.ar
# Now performing additional API calls on site #7: dados.ufrn.br
# Now performing additional API calls on site #8: data.odw.tw
# Now performing additional API calls on site #9: data.gov.ie
# Now performing additional API calls on site #10: geocatalogus.nl
# Now performing additional API calls on site #11: dados.mda.gov.br
# Now performing additional API calls on site #12: data.mariupolrada.gov.ua
# Now performing additional API calls on site #13: dados.ufop.br
# Now performing additional API calls on site #14: data.barrowbc.gov.uk
# Now performing additional API calls on site #15: opendata.ugr.es
# Now performing additional API calls on site #16: dados.uffs.edu.br
# Now performing additional API calls on site #17: portal.igg.ac.mn
# Now performing additional API calls on site #18: data.ed.gov
# Now performing additional API calls on site #19: opendata.gov.mn
# Now performing additional API calls on site #20: daten.rlp.de
# Now performing additional API calls on site #21: data.gov.il
# Now performing additional API calls on site #22: www.opengov-muenchen.de
# Now performing additional API calls on site #23: dados.df.gov.br
# Now performing additional API calls on site #24: ckan.jbrj.gov.br
# Now performing additional API calls on site #25: data.bart.gov
# Now performing additional API calls on site #26: opendata.plzen.eu
# Now performing additional API calls on site #27: ckan.gsi.go.jp
# Now performing additional API calls on site #28: data.nbco.gov.ie
# Now performing additional API calls on site #29: data.gov.mk
# Now performing additional API calls on site #30: data.imr.gov.ua
# Now performing additional API calls on site #31: dados.cvm.gov.br
# Now performing additional API calls on site #32: data.techno-science.ca
# Now performing additional API calls on site #33: data.ok.gov
# Now performing additional API calls on site #34: datos.santander.es
# Now performing additional API calls on site #35: geodm.gr
# Now performing additional API calls on site #36: gifu-opendata.pref.gifu.lg.jp
# Now performing additional API calls on site #37: gisdata.mn.gov
# Now performing additional API calls on site #38: opendata-ajuntament.barcelona.cat
# Now performing additional API calls on site #39: dati.trentino.it
# Now performing additional API calls on site #40: catalogue.data.wa.gov.au
# Now performing additional API calls on site #41: flooddata.ses.nsw.gov.au
# Now performing additional API calls on site #42: datos.jus.gob.ar
# Now performing additional API calls on site #43: www.data.go.jp
# Now performing additional API calls on site #44: dados.ons.org.br
# Now performing additional API calls on site #45: datos.alcobendas.org
# Now performing additional API calls on site #46: data.wonogirikab.go.id
# Now performing additional API calls on site #47: data.pompanobeachfl.gov
# Now performing additional API calls on site #48: 130.179.67.140
# Now performing additional API calls on site #49: dados.cultura.gov.br
# Now performing additional API calls on site #50: opendata.manresa.cat
# Now performing additional API calls on site #51: www.fnde.gov.br
# Now performing additional API calls on site #52: data.milwaukee.gov
# Now performing additional API calls on site #53: www.data.qld.gov.au
# Now performing additional API calls on site #54: unaids.fjelltopp.org
# Now performing additional API calls on site #55: data.england.nhs.uk
# Now performing additional API calls on site #56: data.nhm.ac.uk
# Now performing additional API calls on site #57: data.cbwaterhub.ca
# Now performing additional API calls on site #58: data.montreal.ca
# Now performing additional API calls on site #59: www.civicdata.io
# Now performing additional API calls on site #60: data.stadt-zuerich.ch
# Now performing additional API calls on site #61: datos.transporte.gob.ar
# Now performing additional API calls on site #62: datos.cultura.gob.ar
# Now performing additional API calls on site #63: proyectoarde.org
# Now performing additional API calls on site #64: www.data.brisbane.qld.gov.au
# Now performing additional API calls on site #65: data.bris.ac.uk
# Now performing additional API calls on site #66: catalog.industrie.gov.tn
# Now performing additional API calls on site #67: hubofdata.ru
# Now performing additional API calls on site #68: opendata.picturae.com
# Now performing additional API calls on site #69: data.datahub.freightaustralia.gov.au
# Now performing additional API calls on site #70: opendata.aragon.es
# Now performing additional API calls on site #71: opendata.awt.be
# Now performing additional API calls on site #72: opendata.bayern.de
# Now performing additional API calls on site #73: opendata.leipzig.de
# Now performing additional API calls on site #74: demo.ckan.org
# Now performing additional API calls on site #75: datos.qroo.gob.mx
# Now performing additional API calls on site #76: www.opendata.nhs.scot
# Now performing additional API calls on site #77: datos.gob.cl
# Now performing additional API calls on site #78: data.gov.au
# Now performing additional API calls on site #79: data.gov.hr
# Now performing additional API calls on site #80: agridata.tn
# Now performing additional API calls on site #81: data.stat.pref.miyazaki.lg.jp
# Now performing additional API calls on site #82: opendata.eol.org
# Now performing additional API calls on site #83: dadosabertos.iftm.edu.br
# Now performing additional API calls on site #84: opendata.hu
# Now performing additional API calls on site #85: opendatabc.ca
# Now performing additional API calls on site #86: liityntakatalogi.suomi.fi
# Now performing additional API calls on site #87: opendata.adico.fr
# Now performing additional API calls on site #88: data.waterpathogens.org
# Now performing additional API calls on site #89: ckan.earlham.ac.uk
# Now performing additional API calls on site #90: trouver.datasud.fr
# Now performing additional API calls on site #91: data.vic.gov.au
# Now performing additional API calls on site #92: linkeddatacatalog.dws.informatik.uni-mannheim.de
# Now performing additional API calls on site #93: opendata.slavrada.gov.ua
# Now performing additional API calls on site #94: data.yorkopendata.org
# Now performing additional API calls on site #95: datasets.datos.mincyt.gob.ar
# Now performing additional API calls on site #96: datacatalogue.gov.ie
# Now performing additional API calls on site #97: opendata.br7.org.il
# Now performing additional API calls on site #98: data.ontario.ca
# Now performing additional API calls on site #99: open.stavanger.kommune.no
# Now performing additional API calls on site #100: data.missouriepscor.org
# Now performing additional API calls on site #101: www.pigma.org
# Now performing additional API calls on site #102: datosabiertos.ayto-arganda.es
# Now performing additional API calls on site #103: catalog-intaros.nersc.no
# Now performing additional API calls on site #104: dados.antt.gov.br
# Now performing additional API calls on site #105: opendata.camden.gov.uk
# Now performing additional API calls on site #106: bermuda.io
# Now performing additional API calls on site #107: arcticatlas.geobotany.org
# Now performing additional API calls on site #108: datos.caf.com
# Now performing additional API calls on site #109: datasets.fieldsofview.in
# Now performing additional API calls on site #110: datos.gob.ar
# Now performing additional API calls on site #111: ckan.dev.pdnd.italia.it
# Now performing additional API calls on site #112: opendata.meerbusch.de
# Now performing additional API calls on site #113: dados.ufpi.br
# Now performing additional API calls on site #114: sprogteknologi.dk
# Now performing additional API calls on site #115: catalogue.simocean.pt
# Now performing additional API calls on site #116: datos.minfin.gob.gt
# Now performing additional API calls on site #117: ckan.grassroots.tools
# Now performing additional API calls on site #118: dadosabertos.bndes.gov.br
# Now performing additional API calls on site #119: pacificdata.org
# Now performing additional API calls on site #120: drdsi.jrc.ec.europa.eu
# Now performing additional API calls on site #121: data.surrey.ca
# Now performing additional API calls on site #122: dados.agricultura.gov.br
# Now performing additional API calls on site #123: scoda.co.za
# Now performing additional API calls on site #124: www.data.gov.my
# Now performing additional API calls on site #125: data.ehealthireland.ie
# Now performing additional API calls on site #126: ckan.fiware-testbed.jp
# Now performing additional API calls on site #127: opendata.ozwillo.com
# Now performing additional API calls on site #128: datenregister.berlin.de
# Now performing additional API calls on site #129: staging.justicehub.in
# Now performing additional API calls on site #130: donneesquebec.ca
# Now performing additional API calls on site #131: opendata.comune.bari.it
# Now performing additional API calls on site #132: dati.toscana.it
# Now performing additional API calls on site #133: www.data.gv.at
# Now performing additional API calls on site #134: opendata.imet.gr
# Now performing additional API calls on site #135: catalog.data.gov
# Now performing additional API calls on site #136: dados.recife.pe.gov.br
# Now performing additional API calls on site #137: ckancc.g-location-server.site
# Now performing additional API calls on site #138: data.gov.bf
# Now performing additional API calls on site #139: data.msmt.cz
# Now performing additional API calls on site #140: data.kk.dk
# Now performing additional API calls on site #141: dadosabertos.antaq.gov.br
# Now performing additional API calls on site #142: ckan.test-app.vwtelecom.com
# Now performing additional API calls on site #143: ckanmtp.ymparisto.fi
# Now performing additional API calls on site #144: apgc.awi.de
# Now performing additional API calls on site #145: dados.contraosagrotoxicos.org
# Now performing additional API calls on site #146: data.maintenance.org.au
# Now performing additional API calls on site #147: ckan-d4s.d4science.org
# Now performing additional API calls on site #148: dati.ustat.miur.it
# Now performing additional API calls on site #149: demo.datashades.com
# Now performing additional API calls on site #150: dati.comune.matera.it
# Now performing additional API calls on site #151: dato.chequeado.com
# Now performing additional API calls on site #152: knowledge.omaha.org.cn
# Now performing additional API calls on site #153: data.open.guelph.ca
# Now performing additional API calls on site #154: data.tegalkab.go.id
# Now performing additional API calls on site #155: opendatastore.brussels
# Now performing additional API calls on site #156: edx.netl.doe.gov
# Now performing additional API calls on site #157: govdata.de
# Now performing additional API calls on site #158: dataportal.geofyn.dk
# Now performing additional API calls on site #159: canwin-datahub.ad.umanitoba.ca
# Now performing additional API calls on site #160: data.vulekamali.gov.za
# Now performing additional API calls on site #161: www.geo2france.fr
# Now performing additional API calls on site #162: opendata.semarangkota.go.id
# Now performing additional API calls on site #163: data.sba.gov
# Now performing additional API calls on site #164: dados.ufes.br
# Now performing additional API calls on site #165: data-test.toll.no
# Now performing additional API calls on site #166: ckanviz.swige.unhcr.org
# Now performing additional API calls on site #167: datos.gob.sv
# Now performing additional API calls on site #168: dados.gov.br
# Now performing additional API calls on site #169: dadosabertos.prefeitura.poa.br
# Now performing additional API calls on site #170: opendata.mzcr.cz
# Now performing additional API calls on site #171: b2find.eudat.eu
# Now performing additional API calls on site #172: opendata.portdebarcelona.cat
# Now performing additional API calls on site #173: dados.mg.gov.br
# Now performing additional API calls on site #174: datos.techo.org
# Now performing additional API calls on site #175: data.cityofboston.gov
# Now performing additional API calls on site #176: opendata.ayto-caceres.es
# Now performing additional API calls on site #177: datos.misiones.gov.ar
# Now performing additional API calls on site #178: dados.ifsp.edu.br
# Now performing additional API calls on site #179: www.eia.gov
# Now performing additional API calls on site #180: dadosabertos.senado.gov.br
# Now performing additional API calls on site #181: data.opendataportal.at
# Now performing additional API calls on site #182: data.cityofdenton.com
# Now performing additional API calls on site #183: data.zagreb.hr
# Now performing additional API calls on site #184: ckan.project-hobbit.eu
# Now performing additional API calls on site #185: ecaidata.org
# Now performing additional API calls on site #186: geodata.gov.gr
# Now performing additional API calls on site #187: avindata.ca
# Now performing additional API calls on site #188: dados.ibict.br
# Now performing additional API calls on site #189: data.aurin.org.au
# Now performing additional API calls on site #190: beta.ukdataservice.ac.uk
# Now performing additional API calls on site #191: dadosabertos.dataprev.gov.br
# Now performing additional API calls on site #192: opendata.euroinfosicilia.it
# Now performing additional API calls on site #193: datasets.catalogue.data.gov.dk
# Now performing additional API calls on site #194: katalog.data.go.id
# Now performing additional API calls on site #195: datapoa.com.br
# Now performing additional API calls on site #196: poc-api.excise.go.th
# Now performing additional API calls on site #197: usmart.io
# Now performing additional API calls on site #198: hub.satudata.bappenas.go.id
# Now performing additional API calls on site #199: ckan.pearlpv-cost.eu
# Now performing additional API calls on site #200: ckan.africadatahub.org
# Now performing additional API calls on site #201: oasishub.co
# Now performing additional API calls on site #202: dados.ufpr.br
# Now performing additional API calls on site #203: leedsdatamill.org
# Now performing additional API calls on site #204: annuario.comune.fi.it
# Now performing additional API calls on site #205: data.gov.md
# Now performing additional API calls on site #206: opendata.penghu.gov.tw
# Now performing additional API calls on site #207: datos.magyp.gob.ar
# Now performing additional API calls on site #208: edu.mrpam.gov.mn
# Now performing additional API calls on site #209: data.agglo-royan.fr
# Now performing additional API calls on site #210: dadosabertos.unilab.edu.br
# Now performing additional API calls on site #211: datos.do.magnet.cl
# Now performing additional API calls on site #212: opendata.oorlogsbronnen.nl
# Now performing additional API calls on site #213: dataplatformfiets.be
# Now performing additional API calls on site #214: data.sa.gov.au
# Now performing additional API calls on site #215: data.boston.gov
# Now performing additional API calls on site #216: data.city.osaka.lg.jp
# Now performing additional API calls on site #217: www.opendataphilly.org
# Now performing additional API calls on site #218: coat.nina.no
# Now performing additional API calls on site #219: data.houstontx.gov
# Now performing additional API calls on site #220: data.glasgow.gov.uk
# Now performing additional API calls on site #221: www.data.gov.ma
# Now performing additional API calls on site #222: data.birminghamal.gov
# Now performing additional API calls on site #223: dev.opencity.in
# Now performing additional API calls on site #224: opendata.alcoi.org
# Now performing additional API calls on site #225: openbaladiati.tn
# Now performing additional API calls on site #226: data.illinois.gov
# Now performing additional API calls on site #227: data.pkc.gov.uk
# Now performing additional API calls on site #228: mggl-ckan-web.asifarm.it
# Now performing additional API calls on site #229: www.ecaidata.org
# Now performing additional API calls on site #230: data.qld.gov.au
# Now performing additional API calls on site #231: dados.ufcspa.edu.br
# Now performing additional API calls on site #232: nosdonnees.fr
# Now performing additional API calls on site #233: transparencia.enargas.gov.ar
# Now performing additional API calls on site #234: api.foodsecurityportal.org
# Now performing additional API calls on site #235: ckan.pref.shizuoka.jp
# Now performing additional API calls on site #236: radius.amplusdata.io
# Now performing additional API calls on site #237: datosretc.mma.gob.cl
# Now performing additional API calls on site #238: tpbs.igenco.co.th
# Now performing additional API calls on site #239: data.gov.ua
# Now performing additional API calls on site #240: data.vbgov.com
# Now performing additional API calls on site #241: dati.mit.gov.it
# Now performing additional API calls on site #242: ckan.cabi.org
# Now performing additional API calls on site #243: www.donneesquebec.ca
# Now performing additional API calls on site #244: opendatalecce.apposta.biz
# Now performing additional API calls on site #245: podatki.gov.si
# Now performing additional API calls on site #246: data.gov.sk
# Now performing additional API calls on site #247: opendata.slavuta-mvk.gov.ua
# Now performing additional API calls on site #248: data.depositar.io
# Now performing additional API calls on site #249: data.pref.kyoto.lg.jp
# Now performing additional API calls on site #250: ckan.seki.jx.org
# Now performing additional API calls on site #251: data.pemalangkab.go.id
# Now performing additional API calls on site #252: offenedaten.de
# Now performing additional API calls on site #253: kod.brno.cz
# Now performing additional API calls on site #254: opendata.caceres.es
# Now performing additional API calls on site #255: datahub.io
# Now performing additional API calls on site #256: bmckan.cpami.gov.tw
# Now performing additional API calls on site #257: opendata.dev-vlaanderen.be
# Now performing additional API calls on site #258: dartportal.leeds.ac.uk
# Now performing additional API calls on site #259: data.nsw.gov.au
# Now performing additional API calls on site #260: opendata.gov.je
# Now performing additional API calls on site #261: dataportal.gov.tc
# Now performing additional API calls on site #262: dados.ifrn.edu.br
# Now performing additional API calls on site #263: data.open.guelph.ca.
# Now performing additional API calls on site #264: www.tesourotransparente.gov.br
# Now performing additional API calls on site #265: data.kalamazoocity.org
# Now performing additional API calls on site #266: gis-hub.ca
# Now performing additional API calls on site #267: datos.pami.org.ar
# Now performing additional API calls on site #268: data.lexingtonky.gov
# Now performing additional API calls on site #269: opendata.gov.cz
# Now performing additional API calls on site #270: ballaratopendata.org.au
# Now performing additional API calls on site #271: mobidata-bw.de
# Now performing additional API calls on site #272: data.transport.tn
# Now performing additional API calls on site #273: opendata.vlaanderen.be
# Now performing additional API calls on site #274: datos.aytolalaguna.es
# Now performing additional API calls on site #275: data.num.edu.mn
# Now performing additional API calls on site #276: opendata.com.pk
# Now performing additional API calls on site #277: data.gov.gr
# Now performing additional API calls on site #278: opendata.wigan.gov.uk
# Now performing additional API calls on site #279: danepubliczne.gov.pl
# Now performing additional API calls on site #280: portal.ai-global.org
# Now performing additional API calls on site #281: www.openculture.gov.tn
# Now performing additional API calls on site #282: datos.yvera.gob.ar
# Now performing additional API calls on site #283: dados.ifms.edu.br
# Now performing additional API calls on site #284: datosabiertos.bogota.gov.co
# Now performing additional API calls on site #285: data.gov.uk
# Now performing additional API calls on site #286: data.uni-hannover.de
# Now performing additional API calls on site #287: dadosjuventude.ibict.br
# Now performing additional API calls on site #288: datosabiertos.rivasciudad.es
# Now performing additional API calls on site #289: data.pekalongankota.go.id
# Now performing additional API calls on site #290: opendata.city.moka.lg.jp
# Now performing additional API calls on site #291: ckan.govdata.de
# Now performing additional API calls on site #292: opendata.worcesterma.gov
# Now performing additional API calls on site #293: data.hub.zamg.ac.at
# Now performing additional API calls on site #294: taijiang.tw
# Now performing additional API calls on site #295: data.purbalinggakab.go.id
# Now performing additional API calls on site #296: data.birmingham.gov.uk
# Now performing additional API calls on site #297: opendata.abbeville.fr
# Now performing additional API calls on site #298: dados.fortaleza.ce.gov.br
# Now performing additional API calls on site #299: opendatanepal.com
# Now performing additional API calls on site #300: data.agriculturelittorale.fr
# Now performing additional API calls on site #301: adr.unaids.org
# Now performing additional API calls on site #302: data.biodiversity.be
# Now performing additional API calls on site #303: dadosabertos.ifal.edu.br
# Now performing additional API calls on site #304: catalogue.nextgeoss.eu
# Now performing additional API calls on site #305: dataportal.eu-interact.org
# Now performing additional API calls on site #306: www.datapoa.com.br
# Now performing additional API calls on site #307: data.stirling.gov.uk
# Now performing additional API calls on site #308: dados.natal.br
# Now performing additional API calls on site #309: data-gov-ua.org
# Now performing additional API calls on site #310: ckan.geonet-mrn.de
# Now performing additional API calls on site #311: geoscience.data.qld.gov.au
# Now performing additional API calls on site #312: openkg.cn
# Now performing additional API calls on site #313: opendata.praha.eu
# Now performing additional API calls on site #314: opendata.med.kg
# Now performing additional API calls on site #315: opendata.mzp.cz
# Now performing additional API calls on site #316: datos.cali.gov.co
# Now performing additional API calls on site #317: data.gov.sg
# Now performing additional API calls on site #318: data.smartdublin.ie
# Now performing additional API calls on site #319: data.skeenasalmon.info
# Now performing additional API calls on site #320: data.opendevelopmentmekong.net
# Now performing additional API calls on site #321: ouvert.canada.ca
# Now performing additional API calls on site #322: ckan.otevrenamesta.cz
# Now performing additional API calls on site #323: data.overheid.nl
# Now performing additional API calls on site #324: catalogue.cioos.ca
# Now performing additional API calls on site #325: catalogue.ogsl.ca
# Now performing additional API calls on site #326: rotterdamopendata.nl
# Now performing additional API calls on site #327: dataportal.saeri.org
# Now performing additional API calls on site #328: data.london.gov.uk
# Now performing additional API calls on site #329: openbudgetsindia.org
# Now performing additional API calls on site #330: publications.aberdeenshire.gov.uk
# Now performing additional API calls on site #331: dados.ufsm.br
# Now performing additional API calls on site #332: dados.ufrgs.br
# Now performing additional API calls on site #333: dados.al.gov.br
# Now performing additional API calls on site #334: datastore.landcareresearch.co.nz
# Now performing additional API calls on site #335: dados.ufca.edu.br
# Now performing additional API calls on site #336: dados.ifro.edu.br
# Now performing additional API calls on site #337: data.bayanat.ae
# Now performing additional API calls on site #338: library.atticawetlands.eu
# Now performing additional API calls on site #339: data.city.yokohama.lg.jp
# Now performing additional API calls on site #340: portal.opendata.dk
# Now performing additional API calls on site #341: hidalgo1.man.poznan.pl
# Now performing additional API calls on site #342: datos.mininterior.gob.ar
# Now performing additional API calls on site #343: ckan.sansa.saeoss.org
# Now performing additional API calls on site #344: datosabiertos.malaga.eu
# Now performing additional API calls on site #345: healthquery.sh.cn
# Now performing additional API calls on site #346: rdm.inesctec.pt
# Now performing additional API calls on site #347: portal.merit.mn
# Now performing additional API calls on site #348: portal.openbelgium.be
# Now performing additional API calls on site #349: datos.salud.gob.ar
# Now performing additional API calls on site #350: data.wprdc.org
# Now performing additional API calls on site #351: data.whiterockcity.ca
# Now performing additional API calls on site #352: data.tainan.gov.tw
# Now performing additional API calls on site #353: hri.fi
# Now performing additional API calls on site #354: opendata.aachen.de
# Now performing additional API calls on site #355: scidm.nchc.org.tw
# Now performing additional API calls on site #356: opendata.materaevents.it
# Now performing additional API calls on site #357: data.salzburgerland.com
# Now performing additional API calls on site #358: ckan.ev.openindustry.in
# Now performing additional API calls on site #359: www.transparencia.mg.gov.br
# Now performing additional API calls on site #360: data.opendata.durban
# Now performing additional API calls on site #361: datango.infoculture.ru
# Now performing additional API calls on site #362: data.brisbane.qld.gov.au
# Now performing additional API calls on site #363: data.fingrid.fi
# Now performing additional API calls on site #364: datosabiertos.mendoza.gov.ar
# Now performing additional API calls on site #365: data.cilacapkab.go.id
# Now performing additional API calls on site #366: data.gov.cz
# Now performing additional API calls on site #367: datos.veracruzmunicipio.gob.mx
# Now performing additional API calls on site #368: dados.prefeitura.sp.gov.br
# Now performing additional API calls on site #369: data2.cerdi.edu.au
# Now performing additional API calls on site #370: opendata.fortsmithar.gov
# Now performing additional API calls on site #371: www.opendatani.gov.uk
# Now performing additional API calls on site #372: data.ioos.us
# Now performing additional API calls on site #373: opendata.e-land.gov.tw
# Now performing additional API calls on site #374: playdrive-lb-4.ezylink.co
# Now performing additional API calls on site #375: data.coat.no
# Now performing additional API calls on site #376: dataplatform.knmi.nl
# Now performing additional API calls on site #377: dadosabertos.ufersa.edu.br
# Now performing additional API calls on site #378: ngodata.ru
# Now performing additional API calls on site #379: opendata.sjgov.org
# Now performing additional API calls on site #380: dados.ifrs.edu.br
# Now performing additional API calls on site #381: transparencia.enargas.gob.ar
# Now performing additional API calls on site #382: gardentasuna.errenteria.eus
# Now performing additional API calls on site #383: data.acehselatankab.go.id
# Now performing additional API calls on site #384: data.ecosis.org
# Now performing additional API calls on site #385: www.nosdonnees.fr
# Now performing additional API calls on site #386: www.opendata-hro.de
# Now performing additional API calls on site #387: opendata.mmdecin.cz
# Now performing additional API calls on site #388: data.buenosaires.gob.ar
# Now performing additional API calls on site #389: data.opencolorado.org
# Now performing additional API calls on site #390: iatiregistry.org
# Now performing additional API calls on site #391: maps.mapaction.org
# Now performing additional API calls on site #392: datasets.wri.org
# Now performing additional API calls on site #393: test.data.ontario.ca
# Now performing additional API calls on site #394: www.odata.org.il
# Now performing additional API calls on site #395: resiliencedata.nfwf.org
# Now performing additional API calls on site #396: data.balikpapan.go.id
# Now performing additional API calls on site #397: opendata.muenchen.de
# Now performing additional API calls on site #398: buildingamerica.openei.org
# Now performing additional API calls on site #399: dados.rs.gov.br
# Now performing additional API calls on site #400: pe.181.209.63.227.nip.io
# Now performing additional API calls on site #401: www.data.vic.gov.au
# Now performing additional API calls on site #402: data.mmr.cz
# Now performing additional API calls on site #403: data.kcg.gov.tw
# Now performing additional API calls on site #404: data.humdata.org
# Now performing additional API calls on site #405: opendata.cabq.gov
# Now performing additional API calls on site #406: ckan.opendatamalta.com
# Now performing additional API calls on site #407: dados.ifsertao-pe.edu.br
# Now performing additional API calls on site #408: dadosabertos.ifc.edu.br
# Now performing additional API calls on site #409: web.transparencia.pe.gov.br
# Now performing additional API calls on site #410: offenedaten.aachen.de
# Now performing additional API calls on site #411: dados.ifmt.edu.br
# Now performing additional API calls on site #412: data-portal.hpc.swin.edu.au
# Now performing additional API calls on site #413: dataurbe.appcivico.com
# Now performing additional API calls on site #414: data.sgm.ru
# Now performing additional API calls on site #415: data.review.fao.org
# Now performing additional API calls on site #416: datos.ambiente.gob.ar
# Now performing additional API calls on site #417: www.wvcheckbook.gov
# Now performing additional API calls on site #418: dados.ifsuldeminas.edu.br
# Now performing additional API calls on site #419: opendata.hautsdefrance.fr
# Now performing additional API calls on site #420: datasets.seed.nsw.gov.au
# Now performing additional API calls on site #421: data.tn.gov
# Now performing additional API calls on site #422: dados.tce.rs.gov.br
# Now performing additional API calls on site #423: opendata.city-adm.lviv.ua
# Now performing additional API calls on site #424: datar.noip.me
# Now performing additional API calls on site #425: opendata.go.tz
# Now performing additional API calls on site #426: digitalthailand.gistda.or.th
# Now performing additional API calls on site #427: data.tampere.fi
# Now performing additional API calls on site #428: catalogo.datosabiertos.gob.ec
# Now performing additional API calls on site #429: dados.ana.gov.br
# Now performing additional API calls on site #430: datosabiertos.fuengirola.es
# Now performing additional API calls on site #431: opendata.swiss
# Now performing additional API calls on site #432: ckan.pf-sapporo.jp
# Now performing additional API calls on site #433: dadosabertos.bcb.gov.br
# Now performing additional API calls on site #434: opendata.comune.re.it
# Now performing additional API calls on site #435: datosabiertos.mercedes.gob.ar
# Now performing additional API calls on site #436: dataut.vegvesen.no
# Now performing additional API calls on site #437: dataportal.smartcityinnovation.eu
# Now performing additional API calls on site #438: dadesobertes.salou.cat
# Now performing additional API calls on site #439: bigdata-metadados.icict.fiocruz.br
# Now performing additional API calls on site #440: dataworks.calderdale.gov.uk
# Now performing additional API calls on site #441: data.gov.lv
# Now performing additional API calls on site #442: datosestadistica.cba.gov.ar
# Now performing additional API calls on site #443: datos.congresogto.gob.mx
# Now performing additional API calls on site #444: opendatadafni.getmap.gr
# Now performing additional API calls on site #445: docs.entsoe.eu
# Now performing additional API calls on site #446: dati.arpae.it
# Now performing additional API calls on site #447: dados.unifesspa.edu.br
# Now performing additional API calls on site #448: dados.pbh.gov.br
# Now performing additional API calls on site #449: odata.org.il
# Now performing additional API calls on site #450: catalogue.data.gov.bc.ca
# Now performing additional API calls on site #451: ck.govdata.gov.br
# Now performing additional API calls on site #452: sprogressource.digst.govcloud.dk
# Now performing additional API calls on site #453: datos.minem.gob.ar
# Now performing additional API calls on site #454: claircitydata.cbs.nl
# Now performing additional API calls on site #455: repository.participatorylab.org
# Now performing additional API calls on site #456: dados.justica.gov.pt
# Now performing additional API calls on site #457: data.gov.hk
# Now performing additional API calls on site #458: data.amsterdam.nl
# Now performing additional API calls on site #459: data.cdc.gov.tw
# Now performing additional API calls on site #460: data.corkcity.ie
# Now performing additional API calls on site #461: dadosabertos.ufma.br
# Now performing additional API calls on site #462: datos.arsat.com.ar
# Now performing additional API calls on site #463: data.mempawahkab.go.id
# Now performing additional API calls on site #464: data.edincubator.eu
# Now performing additional API calls on site #465: data.sanjoseca.gov
# Now performing additional API calls on site #466: data.staging.sba.gov
# Now performing additional API calls on site #467: data.investigatemidwest.org
# Now performing additional API calls on site #468: datosabiertos.mineduc.gob.gt
# Now performing additional API calls on site #469: data.gov.sa
# Now performing additional API calls on site #470: daten.buergernetz.bz.it
# Now performing additional API calls on site #471: data.env.go.jp
# Now performing additional API calls on site #472: data.nrri.umn.edu
# Now performing additional API calls on site #473: data.europa.eu
# Now performing additional API calls on site #474: dadosabertos.ibama.gov.br
# Now performing additional API calls on site #475: www.dados.univasf.edu.br
# Now performing additional API calls on site #476: transparencia.alhaurindelatorre.es
# Now performing additional API calls on site #477: dados.ufrr.br
# Now performing additional API calls on site #478: data.openstate.eu
# Now performing additional API calls on site #479: phoenixopendata.com
# Now performing additional API calls on site #480: opendata.lisra.jp
# Now performing additional API calls on site #481: bernco.civicdashboards.com
# Now performing additional API calls on site #482: datamx.io
# Now performing additional API calls on site #483: transparenz.karlsruhe.de
# Now performing additional API calls on site #484: data.gov.ro
# Now performing additional API calls on site #485: transportdata.be
# Now performing additional API calls on site #486: opendata.meteo.tn
# Now performing additional API calls on site #487: dataportal.smartme.io
# Now performing additional API calls on site #488: data.aberdeencity.gov.uk
# Now performing additional API calls on site #489: catalogo.governoaberto.sp.gov.br
# Now performing additional API calls on site #490: dataportal.cps.chula.ac.th
# Now performing additional API calls on site #491: www.odaa.dk
# Now performing additional API calls on site #492: data.ottawa.ca
# Now performing additional API calls on site #493: data.pontianakkota.go.id
# Now performing additional API calls on site #494: datenportal.pado-projekt.de
# Now performing additional API calls on site #495: www.donostia.eus
# Now performing additional API calls on site #496: data.sanantonio.gov
# Now performing additional API calls on site #497: opendata.kp.gov.pk
# Now performing additional API calls on site #498: data.edinburghopendata.info
# Now performing additional API calls on site #499: salforddataquay.uk
# Now performing additional API calls on site #500: basedosdados.org
# Now performing additional API calls on site #501: opendata.nhsbsa.net
# Now performing additional API calls on site #502: dadosabertos.ufms.br
# Now performing additional API calls on site #503: dadosabertos.capes.gov.br
# Now performing additional API calls on site #504: opendata.angus.gov.uk
# Now performing additional API calls on site #505: open.canada.ca
# Now performing additional API calls on site #506: data.doi.gov
# Now performing additional API calls on site #507: offenedaten.frankfurt.de
# Now performing additional API calls on site #508: dados.ufpel.edu.br
# Now performing additional API calls on site #509: finrahoitus.fi
# Now performing additional API calls on site #510: www.basedosdados.org
# Now performing additional API calls on site #511: datospublicos.org
# Now performing additional API calls on site #512: avoindata.fi
# Now performing additional API calls on site #513: data.treasury.ri.gov
# Now performing additional API calls on site #514: dados.mma.gov.br
# Now performing additional API calls on site #515: donnees.ville.montreal.qc.ca
# Now performing additional API calls on site #516: www.transparencia.dadosabertos.mg.gov.br
# Now performing additional API calls on site #517: www.a2gov.org
# Now performing additional API calls on site #518: acikveri.sahinbey.bel.tr
# Now performing additional API calls on site #519: opendata.tarragona.cat
# Now performing additional API calls on site #520: opendata.terrassa.cat
# Now performing additional API calls on site #521: open.alabama.gov
# Now performing additional API calls on site #522: open.data.al
# Now performing additional API calls on site #523: open.alberta.ca
# Now performing additional API calls on site #524: algeria.opendataforafrica.org
# Now performing additional API calls on site #525: www.alkmaar.nl
# Now performing additional API calls on site #526: www.allerdale.gov.uk
# Now performing additional API calls on site #527: www.gisdro.nl
# Now performing additional API calls on site #528: www.amsterdamopendata.nl
# Now performing additional API calls on site #529: www.juntadeandalucia.es
# Now performing additional API calls on site #530: data.angers.fr
# Now performing additional API calls on site #531: arvada.org
# Now performing additional API calls on site #532: risp.asturias.es
# Now performing additional API calls on site #533: data.vorarlberg.gv.at
# Now performing additional API calls on site #534: www1.data.antarctica.gov.au
# Now performing additional API calls on site #535: ada.edu.au
# Now performing additional API calls on site #536: aihw.gov.au
# Now performing additional API calls on site #537: observa.gijon.es
# Now performing additional API calls on site #538: datos.madrid.es
# Now performing additional API calls on site #539: badalona.cat
# Now performing additional API calls on site #540: www.bahrain.bh
# Now performing additional API calls on site #541: www.data.gov.bh
# Now performing additional API calls on site #542: www.banffopendata.ca
# Now performing additional API calls on site #543: data.bathhacked.org
# Now performing additional API calls on site #544: www.bcn.cat
# Now performing additional API calls on site #545: www.bjdata.gov.cn
# Now performing additional API calls on site #546: daten.berlin.de
# Now performing additional API calls on site #547: www.bilbao.net
# Now performing additional API calls on site #548: www.birmingham.gov.uk
# Now performing additional API calls on site #549: www.bizstats.co.uk
# Now performing additional API calls on site #550: dati.comune.bologna.it
# Now performing additional API calls on site #551: hubmaps1.cityofboston.gov
# Now performing additional API calls on site #552: data.visitprovence.com
# Now performing additional API calls on site #553: www.brampton.ca
# Now performing additional API calls on site #554: opengov.brandon.ca
# Now performing additional API calls on site #555: opendata.bristol.gov.uk
# Now performing additional API calls on site #556: budget.gov.ru
# Now performing additional API calls on site #557: cms.burlington.ca
# Now performing additional API calls on site #558: opendata.busan.go.kr
# Now performing additional API calls on site #559: www.data.ca.gov
# Now performing additional API calls on site #560: opendata.gov.nl.ca
# Now performing additional API calls on site #561: app.kitchener.ca
# Now performing additional API calls on site #562: climate.calcommons.org
# Now performing additional API calls on site #563: www.caib.es
# Now performing additional API calls on site #564: cityonline.calgary.ca
# Now performing additional API calls on site #565: chhs.data.ca.gov
# Now performing additional API calls on site #566: opendata.cambridgeshireinsight.org.uk
# Now performing additional API calls on site #567: www.linkedopencamera.it
# Now performing additional API calls on site #568: cameroon.opendataforafrica.org
# Now performing additional API calls on site #569: caboverde.opendataforafrica.org
# Now performing additional API calls on site #570: centraldedados.pt
# Now performing additional API calls on site #571: dati.camera.it
# Now performing additional API calls on site #572: www.chatham-kent.ca
# Now performing additional API calls on site #573: data.chattlibrary.org
# Now performing additional API calls on site #574: data.cityofchicago.org
# Now performing additional API calls on site #575: datos.bcn.cl
# Now performing additional API calls on site #576: www.consejotransparencia.cl
# Now performing additional API calls on site #577: www.chilliwack.com
# Now performing additional API calls on site #578: govinfo.nlc.gov.cn
# Now performing additional API calls on site #579: opendurham.nc.gov
# Now performing additional API calls on site #580: data.honolulu.gov
# Now performing additional API calls on site #581: data-avl.opendata.arcgis.com
# Now performing additional API calls on site #582: data.austintexas.gov
# Now performing additional API calls on site #583: data.brla.gov
# Now performing additional API calls on site #584: bouldercolorado.gov
# Now performing additional API calls on site #585: data.culvercity.org
# Now performing additional API calls on site #586: data.detroitmi.gov
# Now performing additional API calls on site #587: data.grcity.us
# Now performing additional API calls on site #588: data.kcmo.org
# Now performing additional API calls on site #589: opendata.lasvegasnevada.gov
# Now performing additional API calls on site #590: data.lacity.org
# Now performing additional API calls on site #591: data.cityofmadison.com
# Now performing additional API calls on site #592: opendata.minneapolismn.gov
# Now performing additional API calls on site #593: data.cityofpaloalto.org
# Now performing additional API calls on site #594: data.cityofpasadena.net
# Now performing additional API calls on site #595: data.providenceri.gov
# Now performing additional API calls on site #596: data.richmondgov.com
# Now performing additional API calls on site #597: data.cityofsacramento.org
# Now performing additional API calls on site #598: data.santa-clarita.com
# Now performing additional API calls on site #599: data.smgov.net
# Now performing additional API calls on site #600: opendata.waterloo.ca
# Now performing additional API calls on site #601: data.weho.org
# Now performing additional API calls on site #602: www.cityscale.com.ua
# Now performing additional API calls on site #603: www.citywindsor.ca
# Now performing additional API calls on site #604: www.civicapps.org
# Now performing additional API calls on site #605: ie.ckan.net
# Now performing additional API calls on site #606: br.ckan.net
# Now performing additional API calls on site #607: it.ckan.net
# Now performing additional API calls on site #608: rs.ckan.net
# Now performing additional API calls on site #609: datos.codeandomexico.org
# Now performing additional API calls on site #610: www.colorado.gov
# Now performing additional API calls on site #611: www.comune.palermo.it
# Now performing additional API calls on site #612: dati.comune.milano.it
# Now performing additional API calls on site #613: dati.comune.roma.it
# Now performing additional API calls on site #614: transparency.ct.gov
# Now performing additional API calls on site #615: data.cookcountyil.gov
# Now performing additional API calls on site #616: www.opendatacordoba.com
# Now performing additional API calls on site #617: www.criik.com
# Now performing additional API calls on site #618: data.csiro.au
# Now performing additional API calls on site #619: data.lacub.fr
# Now performing additional API calls on site #620: cz.ckan.net
# Now performing additional API calls on site #621: arenysdemunt.smartgovs.info
# Now performing additional API calls on site #622: dados.novohamburgo.rs.gov.br
# Now performing additional API calls on site #623: data.daejeon.go.kr
# Now performing additional API calls on site #624: zwgk.dl.gov.cn
# Now performing additional API calls on site #625: www.dallasopendata.com
# Now performing additional API calls on site #626: www.open.canada.ca
# Now performing additional API calls on site #627: www.data.go.kr
# Now performing additional API calls on site #628: www.data.gov
# Now performing additional API calls on site #629: data.mos.ru
# Now performing additional API calls on site #630: www.gov.hk
# Now performing additional API calls on site #631: data.seattle.gov
# Now performing additional API calls on site #632: www.datosabiertos.jcyl.es
# Now performing additional API calls on site #633: data.gv.at
# Now performing additional API calls on site #634: data.linz.gv.at
# Now performing additional API calls on site #635: opendata.admin.ch
# Now performing additional API calls on site #636: data.civicinfo.ca
# Now performing additional API calls on site #637: data.colorado.gov
# Now performing additional API calls on site #638: abertos.xunta.es
# Now performing additional API calls on site #639: data.go.jp
# Now performing additional API calls on site #640: data.go.th
# Now performing additional API calls on site #641: www.data.gouv.fr
# Now performing additional API calls on site #642: data.gov.ph
# Now performing additional API calls on site #643: data.gov.tw
# Now performing additional API calls on site #644: data.hartford.gov
# Now performing additional API calls on site #645: data.lincoln.ac.uk
# Now performing additional API calls on site #646: datameti.go.jp
# Now performing additional API calls on site #647: data.norge.no
# Now performing additional API calls on site #648: www.data-publica.com
# Now performing additional API calls on site #649: data.ukmin.lt
# Now performing additional API calls on site #650: data.ulm.de
# Now performing additional API calls on site #651: data.act.gov.au
# Now performing additional API calls on site #652: datacatalogs.org
# Now performing additional API calls on site #653: www.data.ug
# Now performing additional API calls on site #654: www.datagm.org.uk
# Now performing additional API calls on site #655: datagov.ru
# Now performing additional API calls on site #656: datakilder.no
# Now performing additional API calls on site #657: datalocale.fr
# Now performing additional API calls on site #658: datasf.org
# Now performing additional API calls on site #659: www.datashanghai.gov.cn
# Now performing additional API calls on site #660: opendata.service-bw.de
# Now performing additional API calls on site #661: www.daten.bremen.de
# Now performing additional API calls on site #662: dati.veneto.it
# Now performing additional API calls on site #663: dati.emilia-romagna.it
# Now performing additional API calls on site #664: dati.gov.it
# Now performing additional API calls on site #665: www.dati.lombardia.it
# Now performing additional API calls on site #666: www.datiopen.it
# Now performing additional API calls on site #667: www.datos.misiones.gov.ar
# Now performing additional API calls on site #668: datosabiertos.munlima.gob.pe
# Now performing additional API calls on site #669: catalogodatos.gub.uy
# Now performing additional API calls on site #670: datos.org.py
# Now performing additional API calls on site #671: datos.transparencia.gob.gt
# Now performing additional API calls on site #672: www.datosabiertos.df.gob.mx
# Now performing additional API calls on site #673: www.datosperu.org
# Now performing additional API calls on site #674: data.octo.dc.gov
# Now performing additional API calls on site #675: data.denvergov.org
# Now performing additional API calls on site #676: data.digitaliser.dk
# Now performing additional API calls on site #677: opendata.dc.gov
# Now performing additional API calls on site #678: geoweb.dnv.org
# Now performing additional API calls on site #679: drcongo.opendataforafrica.org
# Now performing additional API calls on site #680: www.dublinked.ie
# Now performing additional API calls on site #681: e-data.gov.ua
# Now performing additional API calls on site #682: earthworks.stanford.edu
# Now performing additional API calls on site #683: data.edmonton.ca
# Now performing additional API calls on site #684: www.eduinfo.co.uk
# Now performing additional API calls on site #685: ckan.emap.fgv.br
# Now performing additional API calls on site #686: data.enel.com
# Now performing additional API calls on site #687: data.sa.edu.au
# Now performing additional API calls on site #688: gptogc.esri.com
# ...
# Now performing additional API calls on site #805: www.rdno.ca
# Now performing additional API calls on site #806: www.opendatanottingham.org.uk
# Now performing additional API calls on site #807: www.nysenate.gov
# Now performing additional API calls on site #808: nycopendata.socrata.com
# Now performing additional API calls on site #809: oakville.ca
# Now performing additional API calls on site #810: opendata.odiqueensland.org.au
# Now performing additional API calls on site #811: www.offenes-jena.de
# Now performing additional API calls on site #812: www.mo.gov
# Now performing additional API calls on site #813: www.floridahasarighttoknow.com
# Now performing additional API calls on site #814: www.rdos.bc.ca
# Now performing additional API calls on site #815: www.data.gov.om
# Now performing additional API calls on site #816: www.ost.pt
# Now performing additional API calls on site #817: www.ontario.ca
# Now performing additional API calls on site #818: www.opendatahub.it
# Now performing additional API calls on site #819: www.opendata.tw
# Now performing additional API calls on site #820: www.comune.trento.it
# Now performing additional API calls on site #821: www.saudi.gov.sa
# Now performing additional API calls on site #822: data.wien.gv.at
# Now performing additional API calls on site #823: www.tn.gov
# Now performing additional API calls on site #824: data.ny.gov
# Now performing additional API calls on site #825: cat.open.org.nz
# Now performing additional API calls on site #826: data.openva.com
# Now performing additional API calls on site #827: opendata.antwerpen.be
# Now performing additional API calls on site #828: www.datos.gov.co
# Now performing additional API calls on site #829: dati.comune.firenze.it
# Now performing additional API calls on site #830: opendataforafrica.org
# Now performing additional API calls on site #831: opendatakosovo.org
# Now performing additional API calls on site #832: sierraleone.opendataforafrica.org
# Now performing additional API calls on site #833: opendata.gov.sl
# Now performing additional API calls on site #834: catalog.opendata.in.th
# Now performing additional API calls on site #835: www.opendevelopmentcambodia.net
# Now performing additional API calls on site #836: www.openkent.org.uk
# Now performing additional API calls on site #837: data.raleighnc.gov
# Now performing additional API calls on site #838: open.stockholm.se
# Now performing additional API calls on site #839: www.openumea.se
# Now performing additional API calls on site #840: openaid.se
# Now performing additional API calls on site #841: data.baltimorecity.gov
# Now performing additional API calls on site #842: opendata.enschede.nl
# Now performing additional API calls on site #843: www.opendata.go.ke
# Now performing additional API calls on site #844: opendata.bonn.de
# Now performing additional API calls on site #845: opendata.brussel.be
# Now performing additional API calls on site #846: www.opendata.hu
# Now performing additional API calls on site #847: opendata.lv
# Now performing additional API calls on site #848: www.opendatabc.ca
# Now performing additional API calls on site #849: www.manchester.gov.uk
# Now performing additional API calls on site #850: www.opendataterritorioenna.it
# Now performing additional API calls on site #851: opendoor.ky.gov
# Now performing additional API calls on site #852: en.openei.org
# Now performing additional API calls on site #853: opengov.es
# Now performing additional API calls on site #854: www.opengov.se
# Now performing additional API calls on site #855: opengovdata.ru
# Now performing additional API calls on site #856: open.nrw
# Now performing additional API calls on site #857: www.openstreetmap.org
# Now performing additional API calls on site #858: oppnadata.se
# Now performing additional API calls on site #859: www.orebro.se
# Now performing additional API calls on site #860: data.oregon.gov
# Now performing additional API calls on site #861: www.os.amsterdam.nl
# Now performing additional API calls on site #862: www.ouka.fi
# Now performing additional API calls on site #863: cartolleida.paeria.es
# Now performing additional API calls on site #864: pamplona.es
# Now performing additional API calls on site #865: opendata.paris.fr
# Now performing additional API calls on site #866: www.comune.pv.it
# Now performing additional API calls on site #867: picandmix.org.uk
# Now performing additional API calls on site #868: www.dati.piemonte.it
# Now performing additional API calls on site #869: opendata.jccm.es
# Now performing additional API calls on site #870: www.despesapublica.com
# Now performing additional API calls on site #871: princegeorge.ca
# Now performing additional API calls on site #872: opendata.provincia.lucca.it
# Now performing additional API calls on site #873: www.opendata.provincia.roma.it
# Now performing additional API calls on site #874: www.dados.gov.pt
# Now performing additional API calls on site #875: pub.uni-bielefeld.de
# Now performing additional API calls on site #876: www.infomex.org.mx
# Now performing additional API calls on site #877: publicdata.belgium.be
# Now performing additional API calls on site #878: publicdata.eu
# Now performing additional API calls on site #879: www.dati.puglia.it
# Now performing additional API calls on site #880: data.gouv.qc.ca
# Now performing additional API calls on site #881: qldspatial.information.qld.gov.au
# Now performing additional API calls on site #882: donnees.ville.quebec.qc.ca
# Now performing additional API calls on site #883: rcongo.opendataforafrica.org
# Now performing additional API calls on site #884: www.recovery.gov
# Now performing additional API calls on site #885: data.reddeer.ca
# Now performing additional API calls on site #886: data.redbridge.gov.uk
# Now performing additional API calls on site #887: www.regina.ca
# Now performing additional API calls on site #888: www.york.ca
# Now performing additional API calls on site #889: opendata.peelregion.ca
# Now performing additional API calls on site #890: www.regionofwaterloo.ca
# Now performing additional API calls on site #891: www.data.rennes-metropole.fr
# Now performing additional API calls on site #892: researchdata.ands.org.au
# Now performing additional API calls on site #893: www.ri.gov
# Now performing additional API calls on site #894: www.opendata.larochelle.fr
# Now performing additional API calls on site #895: www.rotterdamopendata.nl
# Now performing additional API calls on site #896: rwanda.opendataforafrica.org
# Now performing additional API calls on site #897: www.saanich.ca
# Now performing additional API calls on site #898: www.salford.gov.uk
# Now performing additional API calls on site #899: sdappschallenge.com
# Now performing additional API calls on site #900: data.cityofsantacruz.com
# Now performing additional API calls on site #901: www.opendata71.fr
# Now performing additional API calls on site #902: www.sardegnageoportale.it
# Now performing additional API calls on site #903: opendata-saskatoon.cloudapp.net
# Now performing additional API calls on site #904: data.sejong.go.kr
# Now performing additional API calls on site #905: www.semic.eu
# Now performing additional API calls on site #906: dati.senato.it
# Now performing additional API calls on site #907: senegal.opendataforafrica.org
# Now performing additional API calls on site #908: data.seoul.go.kr
# Now performing additional API calls on site #909: donnees.ville.sherbrooke.qc.ca
# Now performing additional API calls on site #910: slip.landgate.wa.gov.au
# Now performing additional API calls on site #911: open.gsnd.net
# Now performing additional API calls on site #912: data.jeonnam.go.kr
# Now performing additional API calls on site #913: web1.capetown.gov.za
# Now performing additional API calls on site #914: municipalmoney.gov.za
# Now performing additional API calls on site #915: municipaldata.treasury.gov.za
# Now performing additional API calls on site #916: southafrica.opendataforafrica.org
# Now performing additional API calls on site #917: vulekamali.gov.za
# Now performing additional API calls on site #918: southsudan.opendataforafrica.org
# Now performing additional API calls on site #919: datos.gob.es
# Now performing additional API calls on site #920: data.sunshinecoast.qld.gov.au
# Now performing additional API calls on site #921: www.statcentral.ie
# Now performing additional API calls on site #922: www.nebraska.gov
# Now performing additional API calls on site #923: data.wa.gov
# Now performing additional API calls on site #924: www.strathcona.ca
# Now performing additional API calls on site #925: data.suomi.fi
# Now performing additional API calls on site #926: www.surrey.ca
# Now performing additional API calls on site #927: www.sutton.gov.uk
# Now performing additional API calls on site #928: data.taichung.gov.tw
# Now performing additional API calls on site #929: tampere.fi
# Now performing additional API calls on site #930: tanzania.opendataforafrica.org
# Now performing additional API calls on site #931: www.texas.gov
# Now performing additional API calls on site #932: www.texastransparency.org
# Now performing additional API calls on site #933: data.pm.go.th
# Now performing additional API calls on site #934: www.thunderbay.ca
# Now performing additional API calls on site #935: data.tirol.gv.at
# Now performing additional API calls on site #936: www.tol.ca
# Now performing additional API calls on site #937: www.comune.torino.it
# Now performing additional API calls on site #938: www.toronto.ca
# Now performing additional API calls on site #939: data.grandtoulouse.fr
# Now performing additional API calls on site #940: www.trafford.gov.uk
# Now performing additional API calls on site #941: www.turkstat.gov.tr
# Now performing additional API calls on site #942: tunisia.opendataforafrica.org
# Now performing additional API calls on site #943: paikkatietokeskus.lounaispaikka.fi
# Now performing additional API calls on site #944: www.government.ae
# Now performing additional API calls on site #945: data.ulsan.go.kr
# Now performing additional API calls on site #946: open.unhabitat.org
# Now performing additional API calls on site #947: www.undata-api.org
# Now performing additional API calls on site #948: servizi.comune.cesena.fc.it
# Now performing additional API calls on site #949: data.ox.ac.uk
# Now performing additional API calls on site #950: data.southampton.ac.uk
# Now performing additional API calls on site #951: enforcedata.dol.gov
# Now performing additional API calls on site #952: usaspending.gov
# Now performing additional API calls on site #953: www.utah.gov
# Now performing additional API calls on site #954: data.vancouver.ca
# Now performing additional API calls on site #955: dati.venezia.it
# Now performing additional API calls on site #956: www.vernon.ca
# Now performing additional API calls on site #957: vicroadsopendata.vicroadsmaps.opendata.arcgis.com
# Now performing additional API calls on site #958: www.victoria.ca
# Now performing additional API calls on site #959: opendata.bordeaux.fr
# Now performing additional API calls on site #960: datapoint.apa.virginia.gov
# Now performing additional API calls on site #961: opendata.warwickshire.gov.uk
# Now performing additional API calls on site #962: www.welland.ca
# Now performing additional API calls on site #963: data.wa.gov.au
# Now performing additional API calls on site #964: data.whitehorse.ca
# Now performing additional API calls on site #965: data.winnipeg.ca
# Now performing additional API calls on site #966: winnipegelection.ca
# Now performing additional API calls on site #967: developer.worldbank.org
# Now performing additional API calls on site #968: www.wyre.gov.uk
# Now performing additional API calls on site #969: zambia.opendataforafrica.org
# Now performing additional API calls on site #970: datos.zaragoza.es
# Now performing additional API calls on site #971: zimbabwe.opendataforafrica.org
# Now performing additional API calls on site #972: opendata.government.bg
# Now performing additional API calls on site #973: data.hawaii.gov
# Now performing additional API calls on site #974: openaq.org
# Now performing additional API calls on site #975: geoinfo.msl.mt.gov
# Now performing additional API calls on site #976: data-mtfwp.opendata.arcgis.com
# Now performing additional API calls on site #977: github.com
# Now performing additional API calls on site #978: www.dataplatform.nl
# Now performing additional API calls on site #979: data.bandaacehkota.go.id
# Now performing additional API calls on site #980: geo.gob.bo
# Now performing additional API calls on site #981: data.telangana.gov.in
# Now performing additional API calls on site #982: data.g0vhk.io
# Now performing additional API calls on site #983: www.geoguyane.fr
# Now performing additional API calls on site #984: www.otvorenipodatoci.gov.mk
# Now performing additional API calls on site #985: armstat.am
# Now performing additional API calls on site #986: data.gov.rs
# Now performing additional API calls on site #987: data.linz.govt.nz
# Now performing additional API calls on site #988: www.lincolnshire.gov.uk
# Now performing additional API calls on site #989: opendata.tel-aviv.gov.il
# Now performing additional API calls on site #990: data.culturecommunication.gouv.fr
# Now performing additional API calls on site #991: nepalmap.org
# Now performing additional API calls on site #992: dadosabertos.camara.leg.br
# Now performing additional API calls on site #993: api.tcm.ce.gov.br
# Now performing additional API calls on site #994: transparencia.es.gov.br
# Now performing additional API calls on site #995: www.transparencia.go.gov.br
# Now performing additional API calls on site #996: dadosabertos.almg.gov.br
# Now performing additional API calls on site #997: portal.tce.pb.gov.br
# Now performing additional API calls on site #998: www.dadosabertos.pe.gov.br
# Now performing additional API calls on site #999: www.curitiba.pr.gov.br
# Now performing additional API calls on site #1000: data.rio
# Now performing additional API calls on site #1001: portalgeo.pcrj.opendata.arcgis.com
# Now performing additional API calls on site #1002: dados.portoalegre.rs.gov.br
# Now performing additional API calls on site #1003: www.camara.sp.gov.br
# Now performing additional API calls on site #1004: dados.mprs.mp.br
# Now performing additional API calls on site #1005: transparencia.tce.sp.gov.br
# Now performing additional API calls on site #1006: apidadosabertos.tce.rn.gov.br
# Now performing additional API calls on site #1007: www.itabira.cam.mg.gov.br
# Now performing additional API calls on site #1008: www.al.sp.gov.br
# Now performing additional API calls on site #1009: www.transparencia.anapolis.go.gov.br
# Now performing additional API calls on site #1010: www.transparencia.mt.gov.br
# Now performing additional API calls on site #1011: dados.pb.gov.br
# Now performing additional API calls on site #1012: transparencia.campinas.sp.gov.br
# Now performing additional API calls on site #1013: dadosabertos.tce.mg.gov.br
# Now performing additional API calls on site #1014: www.tce.pe.gov.br
# Now performing additional API calls on site #1015: geo.wa.gov
# Now performing additional API calls on site #1016: fiscal.wa.gov
# Now performing additional API calls on site #1017: dadosabertos.cl.df.gov.br
# Now performing additional API calls on site #1018: stat.uz
# Now performing additional API calls on site #1019: data.gov.uz
# Now performing additional API calls on site #1020: opendata.transport.nsw.gov.au
# Now performing additional API calls on site #1021: www.agridata.tn
# Now performing additional API calls on site #1022: www.opendata.ps
# Now performing additional API calls on site #1023: portaldados.ppgau.uff.br
# Now performing additional API calls on site #1024: www.stat.tj
# Now performing additional API calls on site #1025: dadosjusbr.org
# Now performing additional API calls on site #1026: opendata.bratislava.sk
# Now performing additional API calls on site #1027: data.ctdata.org
# Now performing additional API calls on site #1028: data.ci.newark.nj.us
# Now performing additional API calls on site #1029: open.jacksonms.gov
# Now performing additional API calls on site #1030: data.ca.gov
# Now performing additional API calls on site #1031: datagate.snap4city.org

# %%
write_output_file(all_requests_made, "ckan_requests_output.csv")

# %%
def analysis_prep(all_urls_final):
    keys_to_pop_1 = ['api_base_url',
               'site_title',
               'version',
               'locale',
               'extensions',
               'package_list_count',
               'organization_list_count',
               'tag_list_count',
               'oldest_metadata_created_date',
               'most_recent_update_date',
               ]
    keys_to_pop_2 = ['package_list_source_base_or_apibase',
                     'tag_list_source_base_or_apibase',
                     'organization_list_source_base_or_apibase',
                     'dates_source_base_or_apibase']

    for item in all_urls_final:
        for key in keys_to_pop_1:
            if key in item.keys():
#                 if pd.isna(item[key]):
#                     del item[key]
                if item[key] == '':
                    del item[key]
    for item in all_urls_final:
        for keys in keys_to_pop_2:
            if keys in item.keys():
                del item[keys]

#     for item in all_urls_final:
#         if 'oldest_metadata_created_date' in item.keys():
#             item['oldest_metadata_created_date'] = datetime.strptime(item['oldest_metadata_created_date'][:10], '%Y-%m-%d')
#         if 'most_recent_update_date' in item.keys():
#             item['most_recent_update_date'] = datetime.strptime(item['most_recent_update_date'][:10], '%Y-%m-%d')
    all_urls_final_df = pd.DataFrame(all_urls_final)
    all_urls_final_df.to_csv("all_urls_final-jul6.csv")
    return all_urls_final

prepped = analysis_prep(all_requests_made)

# %%
def package_counts(all_urls_final):
    count_of_instances_with_packages = 0
    packages_counts = []
    count_of_datasets_below_1000 = 0
    count_of_datasets_above_50k = 0
    for item in all_urls_final:
        try:
            if item['package_list_count']:
                count_of_instances_with_packages += 1
                packages_counts.append(int(item['package_list_count']))
                if int(item['package_list_count']) < 1001:
                    count_of_datasets_below_1000 += 1
                if int(item['package_list_count']) > 50000:
                    count_of_datasets_above_50k += 1
        except KeyError as e:
            pass
        package_median = statistics.median(packages_counts)
    export_dict = {"count_of_instances_with_packages": count_of_instances_with_packages,
                   "package_median": package_median,
                   "count_of_datasets_below_1000": count_of_datasets_below_1000,
                   "count_of_datasets_above_50k": count_of_datasets_above_50k
    }
    for item in export_dict:
        print(f'{item}: {export_dict[item]}')
        
package_stats = package_counts(prepped)
# Out:
# count_of_instances_with_packages: 365
# package_median: 250
# count_of_datasets_below_1000: 256
# count_of_datasets_above_50k: 13

# %%
def ckan_packages_chart(all_urls_final):
    packages = []
    for row in all_urls_final:
        try:
            package_count = row['package_list_count']
            if package_count != '':
                packages.append(int(package_count))
        except KeyError:
            pass

    sorted_sizes_adjusted = sorted([1 if s == 0 else s for s in packages], reverse=True)
    sizes_plus_ranks = {'rank': range(len(sorted_sizes_adjusted)), 'package_count': sorted_sizes_adjusted}

    warnings.filterwarnings("ignore", category=UserWarning)
    fig, ax = plt.subplots(figsize=(10,10))
    seaborn.histplot(data=sizes_plus_ranks, x='package_count', log_scale=(True, False))
    ax.set_xlabel("Count of Datasets per Instance")
    ax.set_ylabel("Number of Instances")
    plt.xticks(rotation=45)
    ax.set_xticklabels(['0', '.1', '1', '10', '100', '1000', '10,000', '100,000', '1,000,000'])
    plt.title("Fig. 1: Bar Chart of CKAN Instance Size (Measured in Number of Datasets)\n", size=8)
    plt.savefig("packages_chart.png")
    plt.show()

ckan_packages_chart(prepped)

# %%
def time_calcs(all_urls_final):
    year_list = []
    time_dict = {}
    today = datetime.today()
    url_list = []
    overall_count = 0
    for y in range(2007, 2024):
        annual_count = 0
        age = 0
        timedeltas = []
        age_pct = []
        for item in all_urls_final:
            try:
                if 'oldest_metadata_created_date' in item.keys():
                    if 'most_recent_update_date' in item.keys():
                        if type(item['oldest_metadata_created_date']) == datetime:
                            if type(item['most_recent_update_date']) == datetime:
                                year_list.append((item['oldest_metadata_created_date'], item['most_recent_update_date']))
                                if int(item['oldest_metadata_created_date'].strftime('%Y')) == y:
                                    annual_count+=1
                                    overall_count+=1
                                    oldest = item['oldest_metadata_created_date']
                                    most_recent = item['most_recent_update_date']
                                    timedeltas.append(int((most_recent-oldest).days))
                                    age_pct.append(int((most_recent-oldest).days) / int((today - oldest).days))
                                    url_list.append(item['source_url'])

            except Exception as e:
                print(item['oldest_metadata_created_date'], item['source_url'], e)
        if len(timedeltas)>0:
            avg_age = round((sum(timedeltas)/len(timedeltas))/365, 2)
            median_age = round(statistics.median(timedeltas)/365, 2)
        else:
            avg_age = 0
            median_age = 0
        if len(age_pct)>0:
            age_pct_amt = round(((sum(age_pct))/(len(age_pct))), 2)
        else:
            age_pct_amt = 0
        time_dict[y] = {"year":y, "count": annual_count, "avg_age":avg_age, "median":median_age, "average_lifespan":age_pct_amt}
    return(time_dict, overall_count)

time_dict, overall_count = time_calcs(prepped)
# Out:
# 2023-07-06 13:16:41.055059 https://ckan-d4s.d4science.org division by zero
# 2023-07-06 05:55:57.411025 http://b2find.eudat.eu division by zero
# 2023-07-06 14:48:46.355723 http://dados.ana.gov.br division by zero

# %%
def graphing(time_dict):
    time_dict = sorted(time_dict.items())
    list_of_time_dicts = [item[1] for item in time_dict]
    count_list = []
    age_list = []
    lifespan_list = []
    for item in list_of_time_dicts:
        if item["count"] > 0:
            count_list.append((item["year"], item["count"]))
            age_list.append((item["year"], item["avg_age"]))
            lifespan_list.append((item["year"], item["average_lifespan"]))

    x_axis_count, y_axis_count = zip(*count_list)
    x_axis_age, y_axis_age = zip(*age_list)
    x_axis_life, y_axis_life = zip(*lifespan_list)

    fig, ax = plt.subplots(figsize=(8, 8))
    bars = ax.bar(x_axis_count, y_axis_count)
    ax.set_xlabel("Year Launched", fontsize=12)
    ax.set_ylabel("Count of Instances", fontsize=12)
    x_list = [2007, 2011, 2013, 2015, 2017, 2019, 2021, 2023]
    x = np.array(x_list)
    plt.xticks(x, fontsize=12)
    ax.bar_label(bars)
    ax.set_xlim(2006, 2024)
    plt.title("Fig. 3: Count of CKAN Instances Launched Per Year, 2007-2023\n", size=8)
    plt.savefig("ckan_per_year.png")

    fig, ax = plt.subplots(figsize=(8, 8))
    bars = ax.bar(x_axis_life, y_axis_life, color="#1f77b4")
    ax.set_xlabel("\nYear Launched", fontsize=12)
    ax.set_ylabel("Average Percent of Lifetime Spent Active\n", fontsize=12)
    ax.tick_params(axis='y', labelsize=10)
    x_list = [2007, 2011, 2013, 2015, 2017, 2019, 2021, 2023]
    x = np.array(x_list)
    labels = [str(item) for item in x_axis_life]
    plt.xticks(x, fontsize=12)
    rects = ax.patches
    for rect, label in zip(rects, y_axis_count):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2, height + 0.01, label, ha="center", va="bottom")
    fig.savefig("test.png", bbox_inches="tight")
    plt.title("Fig. 4: Average Percent of CKAN Instance 'Lifetime' Spent Active, by Year of Release\n", size=8)
    plt.savefig("ckan_lifetime.png")
    
graphing(time_dict)

# %%
def ckan_version(all_urls_final):
    version_list = []
    for item in all_urls_final:
        try:
            version_list.append(item['version'].split('.')[:2])
        except KeyError:
            pass

    for item in version_list:
        if "b" in item[1]:
            item[1] = item[1].replace("b", "")

    version_3_list = [item for item in version_list if item[0] == '3']
    for item in version_3_list:
        version_list.remove(item)

    version_3_list_final = [item for item in version_3_list if item[1] != "0#datapress"]
    a, b = zip(*version_list)
    version_count = Counter(b)
    version_dict = {f'2.{item}': version_count[item] for item in version_count}

    if len(version_3_list_final) > 0:
        c, d = zip(*version_3_list_final)
        version_3_count = Counter(d)
        version_3_dict = {f'3.{item}': version_3_count[item] for item in version_3_count}
        for item in version_3_dict:
            version_dict[item] = version_3_dict[item]
    x_data = list(sorted(version_dict))
    if '2.10' in x_data:
        if x_data[-1] == '2.10':
            pass
        elif x_data[2] == '2.10':
            x_data.pop(2)
            if x_data[-1] == '2.9':
                x_data.append('2.10')
            else:
                for x in range(len(x_data)):
                    if x_data[x][0] == '3':
                        insert_point = x
                        break
                x_data.insert(insert_point, '2.10')
    y_data = [version_dict[item] for item in x_data]
    return(x_data, y_data)

x_data, y_data = ckan_version(prepped)

# %%
def ckan_version_chart(x_data, y_data):
    fig, ax = plt.subplots(figsize=(8,8))
    bars = ax.bar(x_data, y_data, color="#1f77b4")
    ax.set_xlabel("\nCKAN Version", fontsize=12)
    ax.set_ylabel("Count of CKAN Instances\n", fontsize=12)
    ax.tick_params(axis='y', labelsize=10)
    labels = [str(item) for item in x_data]
    plt.xticks(labels, fontsize=12)
    rects = ax.patches
    for rect, label in zip(rects, y_data):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, height+ 0.01, label, ha="center", va="bottom")
    fig.savefig("test.png", bbox_inches="tight")
    plt.title("Fig. 5: Count of Analyed CKAN Instances Using CKAN Versions 2.0-2.10\n", size=8)
    plt.savefig("version_count.png")
    plt.show()
    
ckan_version_chart(x_data, y_data)
